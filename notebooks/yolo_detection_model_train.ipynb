# %% [markdown]
# # YOLO Detection Model Train

# %%
from ultralytics import YOLO

DATA_YAML = "../configs/data_yolo_split3.yaml"   # <-- detection split
model = YOLO("yolo11m.pt")                       # or "yolo11s.pt"

model.train(
    data=DATA_YAML,
    imgsz=832,
    epochs=200,
    batch=4,
    device=0,
    single_cls=True,

    # Optimizer & schedule
    optimizer="AdamW",
    lr0=2e-4,
    lrf=0.01,
    cos_lr=True,
    warmup_epochs=10,
    weight_decay=7e-4,

    # Augmentations (detection)
    multi_scale=True,
    mosaic=0.0, mixup=0.0, copy_paste=0.0,

    # Geometry
    degrees=180.0,
    translate=0.05,
    scale=0.25,
    shear=3.0,
    perspective=0.0,

    # Flips
    fliplr=0.5,
    flipud=0.1,   

    # Color jitter (conservative)
    hsv_h=0.005,
    hsv_s=0.15,
    hsv_v=0.15,

    # Stability / speed
    amp=True,
    cache="disk",
    workers=2,
    seed=0,
    patience=60,
    save_period=10,
    name="y11m_det_split3_832",
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.223 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.221  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# ...
