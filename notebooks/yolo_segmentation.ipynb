# %% [markdown]
# # Generate Yolo Segmentation Labels From Masks and YOLO 11s-Seg Training
#
# ### Purpose of This Notebook
#
# - **Converts binary masks** to YOLO segmentation labels (`.txt`) using polygon extraction.
# - **Generates labels per folder**, preserving modularity for flexible split composition later.
# - **Trains segmentation models** directly after label generation, using the created YOLO splits.

# %%
# !python ../src/label_generation/masks_to_yolo_seg_labels.py \
  --img_root "../data/detection2/train/images_single" \
  --mask_roots "../data/PolypGen2021_MultiCenterData_v3/data_C1/masks_C1" \
               "../data/PolypGen2021_MultiCenterData_v3/data_C2/masks_C2" \
               "../data/PolypGen2021_MultiCenterData_v3/data_C3/masks_C3" \
               "../data/PolypGen2021_MultiCenterData_v3/data_C4/masks_C4" \
               "../data/PolypGen2021_MultiCenterData_v3/data_C5/masks_C5" \
               "../data/PolypGen2021_MultiCenterData_v3/data_C6/masks_C6" \
  --out_labels "../data/segmentation2/train_yolo_labels/images_single_yolo_labels" \
  --approx_eps 1.5 \
  --min_area_px 25
# Out:
# [progress] 200/1105 | with_mask=153 | instances=167
# [progress] 400/1105 | with_mask=334 | instances=360
# [progress] 600/1105 | with_mask=534 | instances=581
# [progress] 800/1105 | with_mask=718 | instances=800
# [progress] 1000/1105 | with_mask=908 | instances=1010
# [progress] 1105/1105 | with_mask=1013 | instances=1135
# [done] images=1105 | with_mask=1013 | instances=1135 | labels_dir=..\data\segmentation2\train_yolo_labels\images_single_yolo_labels

# %%
# !python ../src/label_generation/masks_to_yolo_seg_labels.py \
  --img_root "../data/detection2/val/images_single" \
  --mask_roots "../data/PolypGen2021_MultiCenterData_v3/data_C1/masks_C1" \
               "../data/PolypGen2021_MultiCenterData_v3/data_C2/masks_C2" \
               "../data/PolypGen2021_MultiCenterData_v3/data_C3/masks_C3" \
               "../data/PolypGen2021_MultiCenterData_v3/data_C4/masks_C4" \
               "../data/PolypGen2021_MultiCenterData_v3/data_C5/masks_C5" \
               "../data/PolypGen2021_MultiCenterData_v3/data_C6/masks_C6" \
  --out_labels "../data/segmentation2/val_yolo_labels/val_images_single_yolo_labels" \
  --approx_eps 1.5 \
  --min_area_px 25
# Out:
# [progress] 139/139 | with_mask=128 | instances=147
# [done] images=139 | with_mask=128 | instances=147 | labels_dir=..\data\segmentation2\val_yolo_labels\val_images_single_yolo_labels

# %% [markdown]
# ## Train Seq Images, Generate Yolo Labels Per Folder

# %%
# !python ../src/label_generation/build_seq_yolo_seg_labels.py \
  --root "../data/detection2/train/seq" \
  --out_labels "../data/segmentation2/train_yolo_labels" \
  --mirror True \
  --approx_eps 1.5 \
  --min_area_px 25
# Out:
# [pos]  seq10: images=25 | with_instances=7
# [pos]  seq11: images=228 | with_instances=136
# [pos]  seq12: images=250 | with_instances=250
# [pos]  seq13: images=250 | with_instances=199
# [pos]  seq14: images=204 | with_instances=157
# [neg]  seq16_neg: wrote 141 empty labels
# [neg]  seq1_neg: wrote 315 empty labels
# [pos]  seq2: images=63 | with_instances=60
# [neg]  seq22_neg: wrote 82 empty labels
# [neg]  seq2_neg: wrote 302 empty labels
# [pos]  seq3: images=15 | with_instances=15
# [neg]  seq3_neg: wrote 40 empty labels
# [pos]  seq4: images=48 | with_instances=46
# [neg]  seq4_neg: wrote 72 empty labels
# [pos]  seq5: images=250 | with_instances=199
# [neg]  seq5_neg: wrote 61 empty labels
# [pos]  seq6: images=91 | with_instances=62
# [neg]  seq6_neg: wrote 90 empty labels
# [neg]  seq7_neg: wrote 207 empty labels
# [pos]  seq8: images=73 | with_instances=54
# [neg]  seq8_neg: wrote 311 empty labels
# [pos]  seq9: images=51 | with_instances=42
# [neg]  seq9_neg: wrote 99 empty labels
#
# [done]
#   positive images: 1548 | with instances: 1227
#   negative images (empty labels): 1720
#   labels root: ..\data\segmentation2\train_yolo_labels

# %% [markdown]
# ## Validation Seq Images, Generate Yolo Labels Per Folder

# %%
# !python ../src/label_generation/build_seq_yolo_seg_labels.py \
  --root "../data/detection2/val/seq" \
  --out_labels "../data/segmentation2/val_yolo_labels" \
  --mirror True \
  --approx_eps 1.5 \
  --min_area_px 25
# Out:
# [neg]  seq15_neg: wrote 278 empty labels
#
# [done]
#   positive images: 0 | with instances: 0
#   negative images (empty labels): 278
#   labels root: ..\data\segmentation2\val_yolo_labels

# %% [markdown]
# ## Kvasir Yolo Labels

# %%
# !python ../src/label_generation/masks_to_yolo_seg_labels.py \
  --img_root "../data/kvasir-seg/images" \
  --mask_roots "../data/kvasir-seg/masks" \
  --out_labels "../data/segmentation2/val_yolo_labels/kvasir_yolo_labels" \
  --approx_eps 1.5 \
  --min_area_px 25
# Out:
# [progress] 200/1000 | with_mask=200 | instances=208
# [progress] 400/1000 | with_mask=400 | instances=423
# [progress] 600/1000 | with_mask=600 | instances=645
# [progress] 800/1000 | with_mask=800 | instances=855
# [progress] 1000/1000 | with_mask=1000 | instances=1060
# [done] images=1000 | with_mask=1000 | instances=1060 | labels_dir=..\data\segmentation2\val_yolo_labels\kvasir_yolo_labels

# %% [markdown]
# ## Single Data Static Augmentation

# %%
# !python ../src/augmentation/augment_single_pos_seg.py \
  --img_root "../data/detection2/train/images_single" \
  --mask_roots "../data/PolypGen2021_MultiCenterData_v3/data_C1/masks_C1" \
               "../data/PolypGen2021_MultiCenterData_v3/data_C2/masks_C2" \
               "../data/PolypGen2021_MultiCenterData_v3/data_C3/masks_C3" \
               "../data/PolypGen2021_MultiCenterData_v3/data_C4/masks_C4" \
               "../data/PolypGen2021_MultiCenterData_v3/data_C5/masks_C5" \
               "../data/PolypGen2021_MultiCenterData_v3/data_C6/masks_C6" \
  --out_images "../data/segmentation2/aug_pos_images" \
  --out_masks  "../data/segmentation2/aug_pos_masks" \
  --out_labels "../data/segmentation2/train_yolo_labels/aug_pos_labels_seg" \
  --copies_per_img 2 \
  --approx_eps 1.5 --min_area_px 25
# Out:
# [info] images found: 1105
# [progress] 100/1105 images processed, total_aug=200
# [progress] 200/1105 images processed, total_aug=400
# [progress] 300/1105 images processed, total_aug=600
# [progress] 400/1105 images processed, total_aug=800
# [progress] 500/1105 images processed, total_aug=1000
# [progress] 600/1105 images processed, total_aug=1200
# [progress] 700/1105 images processed, total_aug=1400
# [progress] 800/1105 images processed, total_aug=1600
# [progress] 900/1105 images processed, total_aug=1800
# [progress] 1000/1105 images processed, total_aug=2000
# [progress] 1100/1105 images processed, total_aug=2200
# [progress] 1105/1105 images processed, total_aug=2210
# [done] Augmented images=2210 written to ..\data\segmentation2\aug_pos_images

# %% [markdown]
# ## Combine All Images and Labels

# %%
# !python ../src/label_generation/combine_images_and_labels.py \
  --train_images_root "../data/detection2/train" \
  --extra_images "../data/segmentation2/aug_neg_images" "../data/segmentation2/aug_pos_images" \
  --labels_root "../data/segmentation2/train_yolo_labels" \
  --output_root "../data/segmentation2/yolo_split2/train"
# Out:
# [info] found 9932 total images before filtering
#
# [done]
#   image-label pairs copied : 9679
#   images skipped (no label): 45
#   duplicates skipped       : 208
#
# Targets:
#   images -> ..\data\segmentation2\yolo_split2\train\images
#   labels -> ..\data\segmentation2\yolo_split2\train\labels

# %%
# !python ../src/label_generation/combine_images_and_labels.py \
  --train_images_root "../data/detection2/val" \
  --extra_images "../data/kvasir-seg/images" \
  --labels_root "../data/segmentation2/val_yolo_labels" \
  --output_root "../data/segmentation2/yolo_split2/val"
# Out:
# [info] found 1417 total images before filtering
#
# [done]
#   image-label pairs copied : 1416
#   images skipped (no label): 0
#   duplicates skipped       : 1
#
# Targets:
#   images -> ..\data\segmentation2\yolo_split2\val\images
#   labels -> ..\data\segmentation2\yolo_split2\val\labels

# %% [markdown]
# # Model Training

# %%
import yaml
from ultralytics import YOLO

# ---- paths ----
DATA_YAML = "../configs/data_seg3.yaml"                    
model = YOLO("yolo11s-seg.pt")


# ---- fine-tune ----
model.train(
    data=DATA_YAML,
    imgsz=832,           
    epochs=200,
    batch=8,             
    device=0,
    single_cls=True,

    # Optimizer & schedule 
    optimizer="AdamW",
    lr0=2e-4,              
    lrf=0.01,
    cos_lr=True,
    warmup_epochs=10,
    weight_decay=7e-4,

    # augmentations
    multi_scale=True,                        
    mosaic=0.0, mixup=0.0, copy_paste=0.0,
    # geometry (union, but stable)
    degrees=180.0,             
    translate=0.05,             # small shifts (≈ random crop spirit)
    scale=0.25,                 # zoom in/out ±25%
    shear=3.0,                  # mild shear to avoid warping shapes too much
    perspective=0.0,            

    # flips
    fliplr=0.5,                
    flipud=0.2,                 

    hsv_h=0.005,                # tiny hue jitter (mucosa colors are sensitive)
    hsv_s=0.18,                 # moderate saturation jitter
    hsv_v=0.20,                 # moderate value (brightness) jitter

    # Stability / speed
    amp=True,
    cache="disk",
    workers=2,
    seed=0,
    patience=60,           
    save_period=10,
    name="aug2_seg3_832",
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.223 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.221  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=disk, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=../configs/data_seg3.yaml, degrees=180.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=200, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.2, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.005, hsv_s=0.18, hsv_v=0.2, imgsz=832, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0002, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-seg.pt, momentum=0.937, mosaic=0.0, multi_scale=True, name=aug2_seg3_832, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=60, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\Betul\Desktop\Projects\Polyp\notebooks\runs\segment\aug2_seg3_832, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.25, seed=0, shear=3.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=True, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.05, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=10, warmup_momentum=0.8, weight_decay=0.0007, workers=2, workspace=None
# Overriding class names with single class.
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1   1474291  ultralytics.nn.modules.head.Segment          [1, 32, 128, [128, 256, 512]]
# YOLO11s-seg summary: 203 layers, 10,082,675 parameters, 10,082,659 gradients, 33.1 GFLOPs
#
# Transferred 555/561 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 1864.91240.7 MB/s, size: 153.0 KB)
# train: Scanning C:\Users\Betul\Desktop\Projects\Polyp\data\segmentation2\yolo_split2\train\labels.cache... 9679 images, 3658 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 9679/9679  0.0s
# train: Caching images (27.5GB Disk): 100% ━━━━━━━━━━━━ 9679/9679 37.2Kit/s 0.3s0.2s
# albumentations: ImageCompression.__init__() got an unexpected keyword argument 'quality_range'
# val: Fast image access  (ping: 0.10.0 ms, read: 859.8595.4 MB/s, size: 129.7 KB)
# val: Scanning C:\Users\Betul\Desktop\Projects\Polyp\data\segmentation2\yolo_split2\val\labels.cache... 1416 images, 289 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1416/1416 1.4Mit/s 0.0s
# val: Caching images (3.2GB Disk): 100% ━━━━━━━━━━━━ 1416/1416 32.9Kit/s 0.0s
# Plotting labels to C:\Users\Betul\Desktop\Projects\Polyp\notebooks\runs\segment\aug2_seg3_832\labels.jpg...
# optimizer: AdamW(lr=0.0002, momentum=0.937) with parameter groups 90 weight(decay=0.0), 101 weight(decay=0.0007), 100 bias(decay=0.0)
# Image sizes 832 train, 832 val
# Using 2 dataloader workers
# Logging results to C:\Users\Betul\Desktop\Projects\Polyp\notebooks\runs\segment\aug2_seg3_832
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       1/200        11G      1.358       2.68      2.325      1.888          3        672: 100% ━━━━━━━━━━━━ 1210/1210 3.9it/s 5:10<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 6.2it/s 14.3s0.2s
#                    all       1416       1206      0.847      0.257      0.591      0.365     0.0417      0.126     0.0185     0.0045
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       2/200      10.6G      1.253      2.249      1.624      1.763          4        544: 100% ━━━━━━━━━━━━ 1210/1210 5.8it/s 3:28<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.0it/s 12.7s0.2s
#                    all       1416       1206       0.74      0.642      0.736       0.51      0.691      0.565      0.632      0.289
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       3/200      9.81G       1.21      2.079      1.428      1.726          4        544: 100% ━━━━━━━━━━━━ 1210/1210 5.8it/s 3:27<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 6.0it/s 14.9s0.2s
#                    all       1416       1206      0.805      0.756       0.83      0.599       0.81      0.756      0.828      0.561
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       4/200      10.1G      1.195      2.024      1.377      1.704          4        640: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:22<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 6.6it/s 13.5s0.2s
#                    all       1416       1206      0.799       0.68      0.781      0.549      0.803      0.678      0.782      0.528
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       5/200        10G      1.165      1.973      1.306      1.676          3        704: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:22<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 6.6it/s 13.5s0.2s
#                    all       1416       1206      0.835      0.774      0.858      0.625      0.837      0.764      0.847      0.598
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       6/200      10.5G      1.133      1.872      1.247      1.639          3        928: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:18<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 6.8it/s 13.1s0.2s
#                    all       1416       1206      0.868      0.762      0.868      0.628      0.867      0.762      0.867       0.63
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       7/200      10.3G      1.121      1.871      1.213      1.632          6       1056: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:19<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.0it/s 12.7s0.2s
#                    all       1416       1206      0.849      0.794      0.867      0.644      0.849      0.799      0.863      0.608
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       8/200      10.4G      1.104       1.84      1.191      1.615          3        544: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:166<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 6.5it/s 13.7s0.2s
#                    all       1416       1206      0.859      0.754      0.853      0.631      0.854      0.757      0.857      0.636
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       9/200      10.2G      1.097      1.792      1.138      1.606          4        768: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:15<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 6.7it/s 13.3s0.2s
#                    all       1416       1206      0.863      0.794       0.88      0.649       0.86      0.794      0.875      0.629
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      10/200      9.92G       1.08      1.801      1.131      1.601          5        672: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:19<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 6.8it/s 13.1s0.2s
#                    all       1416       1206      0.864      0.813      0.895      0.679      0.867       0.81      0.894      0.669
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      11/200      9.97G      1.055      1.736      1.087      1.567          2        928: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:14<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 6.4it/s 13.9s0.2s
#                    all       1416       1206      0.876      0.825      0.905      0.686      0.882       0.83      0.908      0.671
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      12/200      10.1G      1.075      1.741      1.073      1.575          3        480: 100% ━━━━━━━━━━━━ 1210/1210 5.9it/s 3:23<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 6.9it/s 13.0s0.2s
#                    all       1416       1206      0.869      0.817      0.896      0.682      0.869      0.818      0.896      0.668
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      13/200      9.92G      1.033      1.689      1.025      1.542          4        512: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:17<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 6.8it/s 13.2s0.2s
#                    all       1416       1206      0.865      0.828      0.898      0.687      0.874       0.82      0.895      0.672
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      14/200      10.1G       1.05      1.694      1.016      1.554          6        576: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:15<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.0it/s 12.7s0.2s
#                    all       1416       1206      0.849      0.838        0.9      0.695      0.848      0.838      0.902      0.683
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      15/200      10.2G      1.022      1.659     0.9758      1.535          5       1056: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:22<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.2it/s 12.4s0.2s
#                    all       1416       1206      0.879      0.835      0.909      0.708      0.885      0.839      0.909      0.686
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      16/200      10.7G      1.003      1.635     0.9521      1.514          7        672: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:22<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.1it/s 12.6s0.2s
#                    all       1416       1206      0.888      0.833       0.91      0.704      0.888      0.827      0.908      0.686
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      17/200      9.99G      1.011      1.645     0.9603      1.528          4        768: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:20<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.0it/s 12.8s0.2s
#                    all       1416       1206      0.868      0.847       0.91        0.7      0.871      0.852      0.915      0.687
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      18/200      9.62G      1.005      1.634     0.9304      1.497          3        768: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:18<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.2it/s 12.3s0.2s
#                    all       1416       1206      0.905      0.833       0.92       0.71      0.907      0.835      0.918      0.688
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      19/200      9.84G     0.9932      1.603     0.9187      1.512          4        672: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:16<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.0it/s 12.7s0.2s
#                    all       1416       1206      0.884      0.853       0.92      0.716      0.883      0.854      0.921      0.694
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      20/200      9.96G     0.9883       1.61     0.9127      1.486          2        896: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:19<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.2it/s 12.4s0.2s
#                    all       1416       1206      0.909      0.834       0.92      0.719      0.905      0.833      0.918      0.701
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      21/200      9.62G     0.9916      1.606      0.883       1.49          4        736: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:17<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.4it/s 12.1s0.2s
#                    all       1416       1206      0.846      0.881      0.921      0.717      0.885      0.844      0.924      0.697
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      22/200      9.87G     0.9761      1.591     0.8755       1.47          5        416: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:19<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.3it/s 12.1s0.2s
#                    all       1416       1206       0.89      0.869      0.925      0.722      0.893      0.868      0.926      0.707
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      23/200      10.1G     0.9658       1.57     0.8923      1.481          6        736: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:18<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.1it/s 12.6s0.2s
#                    all       1416       1206      0.887      0.839       0.92      0.718      0.891      0.841       0.92      0.699
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      24/200      9.82G     0.9541      1.549     0.8536      1.462          5        672: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:17<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.4it/s 12.1s0.2s
#                    all       1416       1206      0.894      0.821      0.917      0.714      0.895      0.825      0.914      0.694
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      25/200      10.4G     0.9598      1.565     0.8498      1.463          5       1184: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:18<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.1it/s 12.5s0.2s
#                    all       1416       1206      0.905      0.841      0.927      0.728      0.907      0.842      0.928      0.709
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      26/200      9.76G     0.9535      1.538     0.8394      1.456          3        800: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:22<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.3it/s 12.3s0.2s
#                    all       1416       1206      0.899      0.852      0.929       0.73      0.904      0.848      0.928      0.712
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      27/200      9.87G     0.9313      1.517     0.8077      1.436          7        448: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:22<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.3it/s 12.1s0.2s
#                    all       1416       1206      0.915      0.829      0.928      0.733      0.917      0.831      0.928      0.714
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      28/200      11.1G     0.9395      1.521     0.8205      1.448          6       1216: 100% ━━━━━━━━━━━━ 1210/1210 5.8it/s 3:28<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.3it/s 12.1s0.2s
#                    all       1416       1206      0.918      0.846      0.928      0.733      0.919      0.853      0.933      0.717
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      29/200      9.83G     0.9469      1.522     0.8203      1.459          8        480: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:18<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.5it/s 11.9s0.2s
#                    all       1416       1206      0.911      0.864      0.931       0.74      0.912      0.866      0.931      0.718
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      30/200      9.79G     0.9198        1.5     0.8016      1.421          5        896: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:14<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.5it/s 11.9s0.2s
#                    all       1416       1206       0.89      0.877      0.935       0.74      0.894      0.878      0.937      0.718
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      31/200      10.3G     0.9333      1.501     0.7887      1.426          7        448: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:20<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.5it/s 11.8s0.2s
#                    all       1416       1206      0.924      0.853      0.935      0.735      0.928      0.852      0.934       0.72
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      32/200      10.5G     0.9186      1.489     0.7954      1.409          3       1120: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:14<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.7it/s 11.6s0.2s
#                    all       1416       1206      0.915      0.871      0.938      0.743      0.917      0.872      0.937      0.724
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      33/200      10.1G     0.9184      1.505     0.7869      1.421          4        672: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:16<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.7it/s 11.6s0.2s
#                    all       1416       1206      0.913      0.858      0.936       0.74      0.906      0.867      0.932       0.72
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      34/200      10.2G     0.9057      1.475     0.7562      1.403          4        448: 100% ━━━━━━━━━━━━ 1210/1210 6.3it/s 3:14<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.5it/s 11.9s0.2s
#                    all       1416       1206      0.907      0.861      0.934      0.739      0.909      0.864      0.935      0.721
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      35/200      9.71G     0.9099      1.474     0.7573      1.421          5       1024: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:21<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.5it/s 11.9s0.2s
#                    all       1416       1206      0.932      0.847      0.938      0.746      0.894      0.886      0.937      0.725
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      36/200      10.4G     0.9041      1.449     0.7495      1.412          4       1088: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:17<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.5it/s 11.8s0.2s
#                    all       1416       1206      0.923      0.861       0.94      0.742      0.923      0.863      0.941      0.725
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      37/200      9.84G     0.8958      1.451     0.7382      1.409          3        928: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.5it/s 11.8s0.2s
#                    all       1416       1206      0.912      0.876       0.94      0.745      0.918       0.87       0.94      0.727
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      38/200        10G     0.8904      1.437     0.7405      1.399          5        640: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:17<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.5it/s 11.9s0.2s
#                    all       1416       1206      0.899      0.882      0.943      0.751      0.903      0.887      0.943      0.734
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      39/200      9.54G     0.8919      1.455     0.7518      1.406          2        544: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.6it/s 11.7s0.2s
#                    all       1416       1206      0.906      0.877      0.942      0.751      0.907      0.878      0.941      0.731
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      40/200      9.87G     0.9036      1.429     0.7395      1.408          4       1024: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.4it/s 12.0s0.2s
#                    all       1416       1206      0.899       0.87       0.94      0.744      0.898      0.869      0.935      0.728
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      41/200      10.1G     0.8936      1.439      0.717      1.394          6        672: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:17<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.5it/s 11.8s0.2s
#                    all       1416       1206      0.915       0.87      0.942      0.751      0.923      0.867       0.94      0.727
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      42/200      9.69G     0.8802       1.43     0.7245      1.379          4        672: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:19<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.4it/s 12.0s0.2s
#                    all       1416       1206      0.891      0.896      0.945      0.753       0.89      0.896      0.941      0.734
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      43/200      10.1G     0.8797      1.421     0.7052      1.377          5       1088: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:14<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.6it/s 11.7s0.2s
#                    all       1416       1206       0.91      0.881      0.944      0.755      0.913      0.884      0.945      0.737
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      44/200      10.1G     0.8737      1.399     0.7037      1.371          5       1056: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:17<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.7it/s 11.6s0.2s
#                    all       1416       1206      0.916      0.864      0.944      0.758      0.921      0.868      0.943      0.739
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      45/200      9.65G     0.8707      1.409     0.6931      1.368          3        768: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:21<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.7it/s 11.5s0.2s
#                    all       1416       1206      0.932      0.866      0.944      0.758      0.934      0.867      0.944      0.736
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      46/200      10.7G      0.868      1.402      0.695      1.375          4        480: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:21<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.6it/s 11.7s0.2s
#                    all       1416       1206      0.932      0.859      0.945      0.757      0.931      0.863      0.944      0.738
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      47/200      10.2G     0.8579      1.394     0.6831       1.35          5        704: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:16<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.7it/s 11.6s0.2s
#                    all       1416       1206      0.922      0.869      0.943      0.759      0.927      0.874      0.944      0.739
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      48/200      9.71G     0.8557      1.381     0.6679      1.356          3        896: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:17<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.6it/s 11.7s0.2s
#                    all       1416       1206      0.915      0.868      0.944      0.759      0.918      0.871      0.943      0.736
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      49/200      10.1G     0.8528      1.372     0.6614      1.352          3        608: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:19<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.4s0.2s
#                    all       1416       1206      0.903      0.886      0.944      0.758      0.905      0.892      0.946       0.74
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      50/200      10.5G     0.8503      1.376     0.6697      1.345          3        928: 100% ━━━━━━━━━━━━ 1210/1210 6.3it/s 3:13<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.7it/s 11.6s0.2s
#                    all       1416       1206      0.915      0.883      0.946      0.762      0.925      0.883      0.947       0.74
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      51/200      9.58G     0.8583      1.355     0.6555      1.348          4        992: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:18<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.7it/s 11.5s0.2s
#                    all       1416       1206      0.907      0.891      0.947      0.762       0.91      0.897      0.947      0.739
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      52/200      9.88G     0.8492      1.365     0.6556      1.356          7       1024: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:17<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.6it/s 11.7s0.2s
#                    all       1416       1206      0.904      0.891      0.945      0.764      0.913      0.888      0.946      0.743
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      53/200        10G     0.8423      1.353     0.6512      1.346          5        800: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:14<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.5s0.2s
#                    all       1416       1206      0.911      0.886      0.946      0.764      0.918      0.886      0.947      0.744
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      54/200      10.1G     0.8361      1.353     0.6423      1.347          6        896: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:18<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.6it/s 11.7s0.2s
#                    all       1416       1206      0.915      0.883      0.947      0.762      0.919      0.887      0.946      0.741
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      55/200        10G     0.8335      1.343     0.6554      1.332          5        576: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:16<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.7it/s 11.5s0.2s
#                    all       1416       1206      0.915      0.878      0.947      0.765      0.915      0.887      0.948      0.743
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      56/200      10.1G     0.8393      1.347     0.6367      1.345          6        672: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:19<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.9it/s 11.3s0.2s
#                    all       1416       1206      0.918      0.885      0.948      0.768       0.92      0.888      0.948      0.745
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      57/200      9.82G      0.841       1.35     0.6383      1.341          5        960: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:15<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.4s0.2s
#                    all       1416       1206      0.916      0.877      0.946      0.766      0.916      0.883      0.946      0.744
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      58/200       9.6G      0.827      1.331     0.6431      1.332          6        832: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:20<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.7it/s 11.5s0.2s
#                    all       1416       1206      0.922      0.881      0.946      0.768      0.926      0.885      0.948      0.747
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      59/200      10.1G     0.8273      1.335     0.6288      1.327          5        800: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:17<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.5s0.2s
#                    all       1416       1206      0.914      0.891      0.948      0.769       0.92      0.891       0.95      0.747
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      60/200      9.62G     0.8231      1.327     0.6322      1.325          4        800: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:18<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.7it/s 11.6s0.2s
#                    all       1416       1206      0.913      0.893      0.949      0.769      0.916      0.896      0.948      0.746
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      61/200      9.97G     0.8203      1.327     0.6246      1.326          3       1120: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:17<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.9it/s 11.3s0.2s
#                    all       1416       1206      0.909      0.896       0.95       0.77      0.914      0.895      0.947      0.745
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      62/200      10.1G     0.8215      1.317     0.6216      1.327          6        512: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.4s0.2s
#                    all       1416       1206      0.916      0.892      0.951      0.771      0.919      0.893       0.95      0.747
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      63/200      9.95G      0.817      1.304      0.599      1.316          3        896: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:21<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.7it/s 11.5s0.2s
#                    all       1416       1206      0.923      0.886      0.949      0.771      0.927      0.891      0.948      0.748
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      64/200      9.73G     0.8208      1.304     0.6056       1.31          6        896: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:15<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.6it/s 11.7s0.2s
#                    all       1416       1206      0.933      0.882      0.949      0.769      0.934      0.883      0.947      0.746
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      65/200      10.1G     0.7988      1.279       0.59      1.294          6       1024: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:15<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.9it/s 11.3s0.2s
#                    all       1416       1206      0.923      0.891      0.951      0.771      0.921      0.897      0.948      0.746
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      66/200      9.64G     0.8041      1.287      0.588      1.292          4        832: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:14<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.4s0.1s
#                    all       1416       1206      0.931      0.883      0.952      0.773      0.931      0.883      0.949      0.748
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      67/200      9.91G     0.8016      1.286     0.5852      1.294         13        704: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:18<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.9it/s 11.3s0.2s
#                    all       1416       1206      0.918      0.889      0.951      0.775       0.92      0.891      0.949      0.748
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      68/200      9.27G     0.8063      1.287     0.5824      1.303          6        480: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:18<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.9it/s 11.3s0.2s
#                    all       1416       1206       0.93      0.876      0.951      0.775      0.929      0.881      0.948      0.747
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      69/200      10.1G     0.7804      1.268     0.5768      1.288          4        896: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:15<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.9it/s 11.3s0.2s
#                    all       1416       1206      0.934      0.874       0.95      0.774      0.935      0.875      0.948      0.747
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      70/200      9.96G     0.8035       1.26     0.5795       1.29          5        832: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:17<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.9it/s 11.3s0.1s
#                    all       1416       1206      0.932      0.875      0.948      0.774      0.928      0.885      0.947      0.747
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      71/200      9.93G     0.7876      1.252     0.5528      1.283          5        896: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:18<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.4s0.1s
#                    all       1416       1206       0.94      0.871      0.947      0.775      0.937      0.874      0.947      0.749
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      72/200      9.97G     0.7802      1.273     0.5592      1.284          6        736: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:15<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.5s0.2s
#                    all       1416       1206      0.939      0.873      0.947      0.776      0.931      0.883      0.947       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      73/200      10.1G     0.7914      1.257      0.565      1.287          9        416: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:21<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.4s0.2s
#                    all       1416       1206      0.942      0.874      0.947      0.776       0.94      0.879      0.947       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      74/200      9.87G     0.7822      1.248     0.5554      1.282          3        992: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:20<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.4s0.2s
#                    all       1416       1206      0.939      0.875      0.946      0.776      0.938       0.88      0.947       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      75/200      9.79G     0.7826      1.241     0.5442      1.272          6       1056: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:18<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.9it/s 11.2s0.1s
#                    all       1416       1206       0.94      0.874      0.947      0.775       0.94      0.883      0.947      0.749
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      76/200      10.2G     0.7702       1.24     0.5411      1.274          6        768: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:14<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.7it/s 11.5s0.2s
#                    all       1416       1206      0.937       0.88      0.946      0.774       0.94      0.884      0.947      0.749
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      77/200      9.92G     0.7766      1.254     0.5471      1.264          5        512: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:19<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.3s0.2s
#                    all       1416       1206      0.937      0.878      0.947      0.774      0.935      0.883      0.947      0.749
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#      78/200      9.63G     0.7618      1.226     0.5338       1.27          2        832: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:18<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.5s0.1s
#                    all       1416       1206      0.937      0.879      0.947      0.775       0.94      0.881      0.946      0.748
#
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 8.1it/s 11.0s0.2s
#                    all       1416       1206      0.918      0.894      0.946      0.776      0.918      0.894      0.945      0.751
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     118/200      10.2G       0.66      1.072      0.397      1.166          3        448: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:16<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 8.1it/s 11.0s0.1s
#                    all       1416       1206       0.92      0.893      0.946      0.777       0.92      0.893      0.945      0.751
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     119/200      9.64G     0.6661      1.062     0.3955      1.162          5        992: 100% ━━━━━━━━━━━━ 1210/1210 6.3it/s 3:13<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 8.0it/s 11.1s0.1s
#                    all       1416       1206      0.919      0.893      0.946      0.777      0.919      0.893      0.945      0.751
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     120/200      10.2G     0.6565      1.049     0.3898      1.164          7        768: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:22<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 8.0it/s 11.1s0.2s
#                    all       1416       1206      0.918      0.893      0.946      0.776      0.918      0.893      0.944      0.751
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     121/200      9.39G     0.6537      1.044     0.3845      1.153         10        480: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:16<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.9it/s 11.3s0.2s
#                    all       1416       1206      0.922      0.891      0.946      0.776      0.922      0.891      0.944      0.751
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     122/200      9.95G     0.6702      1.057     0.3881      1.164          2        480: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:22<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 8.0it/s 11.1s0.1s
#                    all       1416       1206      0.923      0.891      0.946      0.776      0.923      0.891      0.944      0.751
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     123/200      10.1G     0.6598      1.048     0.3876      1.165          6        672: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:17<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.9it/s 11.3s0.2s
#                    all       1416       1206      0.923      0.891      0.946      0.776      0.923      0.891      0.944       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     124/200      10.1G      0.658      1.043     0.3843      1.159          6        608: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:19<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.7it/s 11.5s0.2s
#                    all       1416       1206      0.924      0.889      0.946      0.776      0.924      0.889      0.944       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     125/200      9.94G     0.6431      1.028     0.3795      1.156          4        608: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:20<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.5s0.2s
#                    all       1416       1206      0.925      0.889      0.946      0.775      0.925      0.889      0.943       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     126/200      9.87G     0.6436      1.036     0.3724       1.15          2        896: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:20<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.7it/s 11.6s0.2s
#                    all       1416       1206      0.925      0.889      0.946      0.776      0.925      0.889      0.943      0.749
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     127/200      10.4G     0.6539       1.04     0.3817      1.156          8        896: 100% ━━━━━━━━━━━━ 1210/1210 5.8it/s 3:29<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.5s0.2s
#                    all       1416       1206      0.925      0.887      0.946      0.776      0.925      0.887      0.943       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     128/200      9.58G     0.6443      1.033     0.3669      1.143          6        640: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:17<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.4s0.2s
#                    all       1416       1206      0.925      0.888      0.946      0.775      0.925      0.888      0.943       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     129/200      9.82G     0.6488       1.04     0.3689      1.151          6       1120: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:15<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.4s0.2s
#                    all       1416       1206      0.926      0.887      0.945      0.776      0.926      0.887      0.943       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     130/200      9.99G      0.632      1.022     0.3766      1.135          6        480: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.5s0.2s
#                    all       1416       1206      0.924      0.887      0.945      0.776      0.925      0.888      0.943      0.751
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     131/200      10.3G     0.6318      1.018     0.3639      1.142          7        608: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:17<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.4s0.2s
#                    all       1416       1206      0.924      0.886      0.944      0.776      0.925      0.887      0.943      0.751
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     132/200      9.66G     0.6391       1.02     0.3626      1.138          6        960: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:23<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.6it/s 11.7s0.2s
#                    all       1416       1206      0.925      0.886      0.944      0.776      0.926      0.887      0.943       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     133/200      9.85G     0.6362      1.018      0.363      1.135          5       1088: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:23<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.5s0.2s
#                    all       1416       1206      0.926      0.886      0.944      0.776      0.927      0.887      0.943       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     134/200      10.3G     0.6304      1.013     0.3558      1.131          3        608: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:20<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 8.1it/s 11.0s0.2s
#                    all       1416       1206      0.926      0.886      0.944      0.776      0.927      0.886      0.942       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     135/200      10.2G     0.6349      1.015      0.358      1.133          5       1184: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:18<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.9it/s 11.3s0.1s
#                    all       1416       1206      0.927      0.885      0.943      0.776      0.928      0.886      0.942       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     136/200      10.9G     0.6277      1.017     0.3539      1.136          5        736: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:20<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 8.0it/s 11.2s0.1s
#                    all       1416       1206       0.93      0.885      0.944      0.776       0.93      0.885      0.941       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     137/200       9.7G     0.6449      1.007     0.3612      1.126          5        640: 100% ━━━━━━━━━━━━ 1210/1210 6.1it/s 3:18<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 8.0it/s 11.1s0.1s
#                    all       1416       1206       0.93      0.885      0.944      0.776       0.93      0.885      0.942       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     138/200      9.87G     0.6245          1     0.3458      1.117          5       1216: 100% ━━━━━━━━━━━━ 1210/1210 6.2it/s 3:17<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 7.8it/s 11.4s0.2s
#                    all       1416       1206      0.929      0.884      0.943      0.776       0.93      0.885      0.941       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     139/200       9.7G     0.6217     0.9983     0.3489       1.13          4        736: 100% ━━━━━━━━━━━━ 1210/1210 6.0it/s 3:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 89/89 8.0it/s 11.1s0.2s
#                    all       1416       1206      0.929      0.884      0.943      0.776       0.93      0.885      0.942       0.75
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#     140/200      10.3G     0.6356          1      0.347      1.139          5       1024: 69% ━━━━━━━━──── 832/1210 5.3it/s 2:19<1:12ss
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 10
#       6 model = YOLO("yolo11s-seg.pt")
#       9 # ---- fine-tune ----
# ---> 10 model.train(
#      11     data=DATA_YAML,
#      12     imgsz=832,
#      13     epochs=200,
#      14     batch=8,
#      15     device=0,
#      16     single_cls=True,
#      17
#      18     # Optimizer & schedule
#      19     optimizer="AdamW",
#      20     lr0=2e-4,
#      21     lrf=0.01,
#      22     cos_lr=True,
#      23     warmup_epochs=10,
#      24     weight_decay=7e-4,
#      25
#      26     # augmentations
#      27     multi_scale=True,
#      28     mosaic=0.0, mixup=0.0, copy_paste=0.0,
#      29     # geometry (union, but stable)
#      30     degrees=180.0,
#      31     translate=0.05,             # small shifts (≈ random crop spirit)
#      32     scale=0.25,                 # zoom in/out ±25%
#      33     shear=3.0,                  # mild shear to avoid warping shapes too much
#      34     perspective=0.0,
#      35
#      36     # flips
#      37     fliplr=0.5,
#      38     flipud=0.2,
#      39
#      40     hsv_h=0.005,                # tiny hue jitter (mucosa colors are sensitive)
#      41     hsv_s=0.18,                 # moderate saturation jitter
#      42     hsv_v=0.20,                 # moderate value (brightness) jitter
#      43
#      44     # Stability / speed
#      45     amp=True,
#      46     cache="disk",
#      47     workers=2,
#      48     seed=0,
#      49     patience=60,
#      50     save_period=10,
#      51     name="aug2_seg3_832",
#      52 )
#
# File c:\Users\Betul\Desktop\Projects\Polyp\polyp_env\Lib\site-packages\ultralytics\engine\model.py:800, in Model.train(self, trainer, **kwargs)
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     798     self.model = self.trainer.model
# --> 800 self.trainer.train()
#     801 # Update model and cfg after training
#     802 if RANK in {-1, 0}:
#
# File c:\Users\Betul\Desktop\Projects\Polyp\polyp_env\Lib\site-packages\ultralytics\engine\trainer.py:240, in BaseTrainer.train(self)
#     237         ddp_cleanup(self, str(file))
#     239 else:
# --> 240     self._do_train()
#
# File c:\Users\Betul\Desktop\Projects\Polyp\polyp_env\Lib\site-packages\ultralytics\engine\trainer.py:449, in BaseTrainer._do_train(self)
#     447 if RANK in {-1, 0}:
#     448     loss_length = self.tloss.shape[0] if len(self.tloss.shape) else 1
# --> 449     pbar.set_description(
#     450         ("%11s" * 2 + "%11.4g" * (2 + loss_length))
#     451         % (
#     452             f"{epoch + 1}/{self.epochs}",
#     453             f"{self._get_memory():.3g}G",  # (GB) GPU memory util
#     454             *(self.tloss if loss_length > 1 else torch.unsqueeze(self.tloss, 0)),  # losses
#     455             batch["cls"].shape[0],  # batch size, i.e. 8
#     456             batch["img"].shape[-1],  # imgsz, i.e 640
#     457         )
#     458     )
#     459     self.run_callbacks("on_batch_end")
#     460     if self.args.plots and ni in self.plot_idx:
#
# File c:\Users\Betul\Desktop\Projects\Polyp\polyp_env\Lib\site-packages\ultralytics\utils\tqdm.py:296, in TQDM.set_description(self, desc)
#     293         self.n += n
#     294         self._display()
# --> 296 def set_description(self, desc: str | None) -> None:
#     297     """Set description."""
#     298     self.desc = desc or ""
#
# KeyboardInterrupt:
