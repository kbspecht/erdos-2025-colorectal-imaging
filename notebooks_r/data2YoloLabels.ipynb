# %%
from pathlib import Path
import cv2
import numpy as np
import json
import shutil, os

# %%
ROOT = Path("../")

# %% [markdown]
# # 1. YOLO Labels for Kvasir Data:

# %%
kvasir_images_path =  ROOT / "data/kvasir-seg/images" 
kvasir_bboxes_path =  ROOT / "data/kvasir-seg/kavsir_bboxes.json"

with open(kvasir_bboxes_path, "r", encoding="utf-8") as f:
    kvasir_labels = json.load(f)

# %%
kvasir_labels
# Out:
# {'cju0qkwl35piu0993l0dewei2': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 38,
#     'ymin': 5,
#     'xmax': 430,
#     'ymax': 338}]},
#  'cju0qoxqj9q6s0835b43399p4': {'height': 1070,
#   'width': 1348,
#   'bbox': [{'label': 'polyp',
#     'xmin': 194,
#     'ymin': 284,
#     'xmax': 913,
#     'ymax': 1049}]},
#  'cju0qx73cjw570799j4n5cjze': {'height': 529,
#   'width': 619,
#   'bbox': [{'label': 'polyp',
#     'xmin': 187,
#     'ymin': 14,
#     'xmax': 543,
#     'ymax': 526}]},
#  'cju0roawvklrq0799vmjorwfv': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 486,
#     'ymin': 42,
#     'xmax': 622,
#     'ymax': 339},
#    {'label': 'polyp', 'xmin': 329, 'ymin': 71, 'xmax': 437, 'ymax': 150},
#    {'label': 'polyp', 'xmin': 619, 'ymin': 151, 'xmax': 622, 'ymax': 285}]},
#  'cju0rx1idathl0835detmsp84': {'height': 528,
#   'width': 617,
#   'bbox': [{'label': 'polyp',
#     'xmin': 292,
#     'ymin': 154,
#     'xmax': 481,
#     'ymax': 375}]},
#  'cju0s2a9ekvms080138tjjpxr': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 379,
#     'ymin': 57,
#     'xmax': 626,
#     'ymax': 431}]},
#  'cju0s690hkp960855tjuaqvv0': {'height': 530,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 223,
#     'ymin': 285,
#     'xmax': 336,
#     'ymax': 434}]},
#  'cju0sr5ghl0nd08789uzf1raf': {'height': 1019,
#   'width': 1214,
#   'bbox': [{'label': 'polyp',
#     'xmin': 393,
#     'ymin': 178,
#     'xmax': 730,
#     'ymax': 488},
#    {'label': 'polyp', 'xmin': 300, 'ymin': 571, 'xmax': 698, 'ymax': 975}]},
#  'cju0sxqiclckk08551ycbwhno': {'height': 531,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 400,
#     'ymin': 278,
#     'xmax': 543,
#     'ymax': 416}]},
#  'cju0t4oil7vzk099370nun5h9': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 203,
#     'ymin': 115,
#     'xmax': 573,
#     'ymax': 526}]},
#  'cju0tl3uz8blh0993wxvn7ly3': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 314,
#     'ymin': 386,
#     'xmax': 370,
#     'ymax': 435}]},
#  'cju0u2g7pmnux0801vkk47ivj': {'height': 530,
#   'width': 611,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 152,
#     'xmax': 367,
#     'ymax': 530}]},
#  'cju0u82z3cuma0835wlxrnrjv': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 293,
#     'ymin': 90,
#     'xmax': 609,
#     'ymax': 531}]},
#  'cju5k7r0yf98c09878csbxb4d': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 228,
#     'ymin': 40,
#     'xmax': 321,
#     'ymax': 134}]},
#  'cju5klveuff6w0871wbibgh3m': {'height': 530,
#   'width': 574,
#   'bbox': [{'label': 'polyp',
#     'xmin': 185,
#     'ymin': 228,
#     'xmax': 308,
#     'ymax': 350}]},
#  'cju5knbbqfipk080128cggukq': {'height': 529,
#   'width': 597,
#   'bbox': [{'label': 'polyp',
#     'xmin': 194,
#     'ymin': 68,
#     'xmax': 595,
#     'ymax': 524}]},
#  'cju5kre09fhka0850h7b1898j': {'height': 528,
#   'width': 618,
#   'bbox': [{'label': 'polyp',
#     'xmin': 317,
#     'ymin': 104,
#     'xmax': 454,
#     'ymax': 317}]},
#  'cju5ktjwofed70817eg58ef7u': {'height': 547,
#   'width': 625,
#   'bbox': [{'label': 'polyp',
#     'xmin': 259,
#     'ymin': 125,
#     'xmax': 496,
#     'ymax': 355}]},
#  'cju5nxkujgscq0817l9gss626': {'height': 531,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 117,
#     'ymin': 272,
#     'xmax': 467,
#     'ymax': 531}]},
#  'cju5nyu31gv8e0871zpk74a2n': {'height': 529,
#   'width': 616,
#   'bbox': [{'label': 'polyp',
#     'xmin': 349,
#     'ymin': 207,
#     'xmax': 505,
#     'ymax': 341}]},
#  'cju5o1vu9gz8a0818eyy92bns': {'height': 547,
#   'width': 421,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 198,
#     'xmax': 199,
#     'ymax': 498}]},
#  'cju5o4pk9h0720755lgp9jq8m': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 350,
#     'ymin': 132,
#     'xmax': 622,
#     'ymax': 515}]},
#  'cju5tenjojp1j0755ms4949h2': {'height': 531,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 44,
#     'ymin': 143,
#     'xmax': 334,
#     'ymax': 434}]},
#  'cju5tgbzhjllu08174ca41eus': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 144,
#     'ymin': 97,
#     'xmax': 459,
#     'ymax': 268}]},
#  'cju5thdbrjp1108715xdfx356': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 279,
#     'ymin': 331,
#     'xmax': 384,
#     'ymax': 433}]},
#  'cju5u4pywk81x0817vn9pe14z': {'height': 531,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 363,
#     'ymin': 265,
#     'xmax': 484,
#     'ymax': 401}]},
#  'cju5u8gz4kj5b07552e2wpkwp': {'height': 531,
#   'width': 571,
#   'bbox': [{'label': 'polyp',
#     'xmin': 168,
#     'ymin': 2,
#     'xmax': 553,
#     'ymax': 375}]},
#  'cju5udcufki0s09874ll1dbr5': {'height': 531,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 225,
#     'ymin': 268,
#     'xmax': 519,
#     'ymax': 513}]},
#  'cju5ufn3skquf0818dhapnhba': {'height': 530,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 236,
#     'ymin': 243,
#     'xmax': 348,
#     'ymax': 373}]},
#  'cju5uget8krjy0818kvywd0zu': {'height': 529,
#   'width': 608,
#   'bbox': [{'label': 'polyp',
#     'xmin': 284,
#     'ymin': 211,
#     'xmax': 455,
#     'ymax': 314}]},
#  'cju5uhrdwkmsu0817ervv91l8': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 401,
#     'ymin': 134,
#     'xmax': 494,
#     'ymax': 224}]},
#  'cju5ukkg6kv7u08011x2b6zl5': {'height': 510,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 118,
#     'ymin': 222,
#     'xmax': 402,
#     'ymax': 464}]},
#  'cju5uxjnol2r509871qv2yeia': {'height': 531,
#   'width': 620,
#   'bbox': [{'label': 'polyp',
#     'xmin': 313,
#     'ymin': 62,
#     'xmax': 483,
#     'ymax': 285}]},
#  'cju5uzmaol56l0817flxh4w9p': {'height': 529,
#   'width': 623,
#   'bbox': [{'label': 'polyp',
#     'xmin': 318,
#     'ymin': 213,
#     'xmax': 441,
#     'ymax': 342}]},
#  'cju5v8pgplg6k0755rvi2t63h': {'height': 530,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 256,
#     'ymin': 231,
#     'xmax': 403,
#     'ymax': 382}]},
#  'cju5vbo6jldrt0871jf6f1700': {'height': 530,
#   'width': 619,
#   'bbox': [{'label': 'polyp',
#     'xmin': 471,
#     'ymin': 143,
#     'xmax': 606,
#     'ymax': 376}]},
#  'cju5vcmrqla7i0817x4sp4pqw': {'height': 482,
#   'width': 612,
#   'bbox': [{'label': 'polyp',
#     'xmin': 284,
#     'ymin': 110,
#     'xmax': 450,
#     'ymax': 267}]},
#  'cju5vgawslbe30987ndeepc1b': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 247,
#     'ymin': 96,
#     'xmax': 603,
#     'ymax': 463}]},
#  'cju5vi4nxlc530817uoqm2m7a': {'height': 530,
#   'width': 619,
#   'bbox': [{'label': 'polyp',
#     'xmin': 231,
#     'ymin': 83,
#     'xmax': 555,
#     'ymax': 425}]},
#  'cju5vutu7ll8w0871dfp92n9p': {'height': 528,
#   'width': 605,
#   'bbox': [{'label': 'polyp',
#     'xmin': 134,
#     'ymin': 104,
#     'xmax': 390,
#     'ymax': 362}]},
#  'cju5vwbr4lhqn0987a1pji0ux': {'height': 530,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 78,
#     'ymin': 288,
#     'xmax': 243,
#     'ymax': 515}]},
#  'cju5vxuc5loxw0818u8xgf45p': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 279,
#     'ymin': 155,
#     'xmax': 483,
#     'ymax': 408}]},
#  'cju5vzjoslpj708186z2fusmz': {'height': 496,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 386,
#     'ymin': 169,
#     'xmax': 530,
#     'ymax': 329}]},
#  'cju5w7xn0lrkq0801f9k0htgx': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 204,
#     'ymin': 207,
#     'xmax': 383,
#     'ymax': 440}]},
#  'cju5waeduln160817w0agirve': {'height': 528,
#   'width': 540,
#   'bbox': [{'label': 'polyp',
#     'xmin': 196,
#     'ymin': 249,
#     'xmax': 381,
#     'ymax': 432}]},
#  'cju5wcc90lu020850mjrxppv6': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 310,
#     'ymin': 175,
#     'xmax': 515,
#     'ymax': 443}]},
#  'cju5wi6bqlxy90755bu227nvb': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 220,
#     'ymin': 129,
#     'xmax': 402,
#     'ymax': 348}]},
#  'cju5wj0faly5008187n6530af': {'height': 530,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 173,
#     'ymin': 179,
#     'xmax': 344,
#     'ymax': 398}]},
#  'cju5wkonqlrl409877y8zvnub': {'height': 547,
#   'width': 627,
#   'bbox': [{'label': 'polyp',
#     'xmin': 308,
#     'ymin': 119,
#     'xmax': 595,
#     'ymax': 413}]},
#  'cju5wmvsdlx1j0871npgj8j4b': {'height': 530,
#   'width': 616,
#   'bbox': [{'label': 'polyp',
#     'xmin': 177,
#     'ymin': 234,
#     'xmax': 347,
#     'ymax': 349}]},
#  'cju5woy82m07m08505dmjg7g1': {'height': 1070,
#   'width': 1348,
#   'bbox': [{'label': 'polyp',
#     'xmin': 448,
#     'ymin': 439,
#     'xmax': 981,
#     'ymax': 1039}]},
#  'cju5wphwwlu3m0987hh3ltg88': {'height': 531,
#   'width': 618,
#   'bbox': [{'label': 'polyp',
#     'xmin': 385,
#     'ymin': 329,
#     'xmax': 523,
#     'ymax': 506}]},
#  'cju0ue769mxii08019zqgdbxn': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 182,
#     'ymin': 83,
#     'xmax': 342,
#     'ymax': 240}]},
#  'cju160wshltz10993i1gmqxbe': {'height': 530,
#   'width': 607,
#   'bbox': [{'label': 'polyp',
#     'xmin': 422,
#     'ymin': 258,
#     'xmax': 513,
#     'ymax': 383}]},
#  'cju17v6ih0u7808783zcbg1jy': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 25,
#     'ymin': 0,
#     'xmax': 361,
#     'ymax': 445}]},
#  'cju1b0y2e396p08558ois175d': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 248,
#     'ymin': 145,
#     'xmax': 380,
#     'ymax': 308}]},
#  'cju1cj3f0qi5n0993ut8f49rj': {'height': 530,
#   'width': 616,
#   'bbox': [{'label': 'polyp',
#     'xmin': 51,
#     'ymin': 204,
#     'xmax': 364,
#     'ymax': 530}]},
#  'cju1dia8hvc6v098827mgffnm': {'height': 528,
#   'width': 616,
#   'bbox': [{'label': 'polyp',
#     'xmin': 334,
#     'ymin': 263,
#     'xmax': 464,
#     'ymax': 403}]},
#  'cju1f15k3w4ct0835cmde6ypo': {'height': 547,
#   'width': 572,
#   'bbox': [{'label': 'polyp',
#     'xmin': 257,
#     'ymin': 242,
#     'xmax': 491,
#     'ymax': 492}]},
#  'cju1fyb1d69et0878muzdak9u': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 209,
#     'ymin': 116,
#     'xmax': 369,
#     'ymax': 397}]},
#  'cju1hs0za7jha0855vj0mdrjt': {'height': 531,
#   'width': 571,
#   'bbox': [{'label': 'polyp',
#     'xmin': 185,
#     'ymin': 183,
#     'xmax': 431,
#     'ymax': 465}]},
#  'cju2i03ptvkiu0799xbbd4det': {'height': 528,
#   'width': 600,
#   'bbox': [{'label': 'polyp',
#     'xmin': 292,
#     'ymin': 125,
#     'xmax': 459,
#     'ymax': 368}]},
#  'cju2ma647l0nj0993ot4deq2q': {'height': 547,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 288,
#     'ymin': 169,
#     'xmax': 459,
#     'ymax': 388},
#    {'label': 'polyp', 'xmin': 229, 'ymin': 424, 'xmax': 421, 'ymax': 547}]},
#  'cju2okvco06xc0799kxe5n1qh': {'height': 530,
#   'width': 577,
#   'bbox': [{'label': 'polyp',
#     'xmin': 130,
#     'ymin': 84,
#     'xmax': 554,
#     'ymax': 420}]},
#  'cju2pmhtr17a00855cvpelzb0': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 319,
#     'ymin': 279,
#     'xmax': 534,
#     'ymax': 496}]},
#  'cju5wrapcm2290818jsh26ppb': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 264,
#     'ymin': 135,
#     'xmax': 468,
#     'ymax': 347}]},
#  'cju5wrrs0m2af0818vmnajbtw': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 334,
#     'ymin': 307,
#     'xmax': 433,
#     'ymax': 419}]},
#  'cju5wtdu4m0im0871mix0yvc0': {'height': 509,
#   'width': 610,
#   'bbox': [{'label': 'polyp',
#     'xmin': 359,
#     'ymin': 47,
#     'xmax': 530,
#     'ymax': 306}]},
#  'cju5wuhm1lwm40987vugqn3vv': {'height': 530,
#   'width': 613,
#   'bbox': [{'label': 'polyp',
#     'xmin': 321,
#     'ymin': 145,
#     'xmax': 521,
#     'ymax': 335}]},
#  'cju5x00l6m5j608503k78ptee': {'height': 529,
#   'width': 554,
#   'bbox': [{'label': 'polyp',
#     'xmin': 46,
#     'ymin': 81,
#     'xmax': 408,
#     'ymax': 488}]},
#  'cju5x15djm7ae0755h8czf6nt': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 315,
#     'ymin': 35,
#     'xmax': 505,
#     'ymax': 276}]},
#  'cju5x28nzm7t907558ocq4bt7': {'height': 546,
#   'width': 597,
#   'bbox': [{'label': 'polyp',
#     'xmin': 211,
#     'ymin': 34,
#     'xmax': 468,
#     'ymax': 297}]},
#  'cju5x7iskmad90818frchyfwd': {'height': 483,
#   'width': 522,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 149,
#     'xmax': 250,
#     'ymax': 453}]},
#  'cju5xjn5mm78b09871spyqhhr': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 301,
#     'ymin': 17,
#     'xmax': 564,
#     'ymax': 317}]},
#  'cju5xkwzxmf0z0818gk4xabdm': {'height': 505,
#   'width': 609,
#   'bbox': [{'label': 'polyp',
#     'xmin': 87,
#     'ymin': 155,
#     'xmax': 400,
#     'ymax': 456}]},
#  'cju5xneamme2p0801qdf7fdwv': {'height': 527,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 131,
#     'ymin': 71,
#     'xmax': 306,
#     'ymax': 221}]},
#  'cju5xopi0md7q0871r1sjc1av': {'height': 546,
#   'width': 568,
#   'bbox': [{'label': 'polyp',
#     'xmin': 381,
#     'ymin': 166,
#     'xmax': 568,
#     'ymax': 411}]},
#  'cju5xq3tdm9fn0987pbedxdg5': {'height': 529,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 297,
#     'ymin': 291,
#     'xmax': 473,
#     'ymax': 429}]},
#  'cju0vtox5ain6099360pu62rp': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 144,
#     'ymin': 99,
#     'xmax': 300,
#     'ymax': 244}]},
#  'cju13cgqmnhwn0988yrainhcp': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 236,
#     'ymin': 263,
#     'xmax': 456,
#     'ymax': 523}]},
#  'cju13fwthn9mq0835gacxgy01': {'height': 529,
#   'width': 623,
#   'bbox': [{'label': 'polyp',
#     'xmin': 346,
#     'ymin': 14,
#     'xmax': 615,
#     'ymax': 261}]},
#  'cju13hp5rnbjx0835bf0jowgx': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 91,
#     'xmax': 219,
#     'ymax': 321}]},
#  'cju14g8o4xui30878gkgbrvqj': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 440,
#     'ymin': 156,
#     'xmax': 544,
#     'ymax': 272}]},
#  'cju14hjh2ob2o0835ouz3r5aa': {'height': 546,
#   'width': 609,
#   'bbox': [{'label': 'polyp',
#     'xmin': 360,
#     'ymin': 247,
#     'xmax': 597,
#     'ymax': 501}]},
#  'cju14pxbaoksp0835qzorx6g6': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 143,
#     'ymin': 8,
#     'xmax': 349,
#     'ymax': 163}]},
#  'cju15czxqp3lv0835jvhgzurz': {'height': 547,
#   'width': 620,
#   'bbox': [{'label': 'polyp',
#     'xmin': 30,
#     'ymin': 92,
#     'xmax': 435,
#     'ymax': 489}]},
#  'cju15jr8jz8sb0855ukmkswkz': {'height': 528,
#   'width': 594,
#   'bbox': [{'label': 'polyp',
#     'xmin': 193,
#     'ymin': 0,
#     'xmax': 540,
#     'ymax': 375},
#    {'label': 'polyp', 'xmin': 356, 'ymin': 0, 'xmax': 485, 'ymax': 1}]},
#  'cju15l5ubz9yh0855b3ivdpse': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 182,
#     'ymin': 199,
#     'xmax': 326,
#     'ymax': 321}]},
#  'cju15mhjczc8z0801kit5c6di': {'height': 546,
#   'width': 624,
#   'bbox': [{'label': 'polyp',
#     'xmin': 344,
#     'ymin': 36,
#     'xmax': 604,
#     'ymax': 285}]},
#  'cju15ptjtppz40988odsm9azx': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 355,
#     'ymin': 140,
#     'xmax': 555,
#     'ymax': 295}]},
#  'cju15wdt3zla10801odjiw7sy': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 303,
#     'ymin': 239,
#     'xmax': 564,
#     'ymax': 529}]},
#  'cju6yxyt0wh080871sqpepu47': {'height': 528,
#   'width': 616,
#   'bbox': [{'label': 'polyp',
#     'xmin': 269,
#     'ymin': 131,
#     'xmax': 413,
#     'ymax': 370}]},
#  'cju6yywx1whbb0871ksgfgf9f': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 299,
#     'ymin': 73,
#     'xmax': 504,
#     'ymax': 255}]},
#  'cju6z1bzbwfq50817b2alatvr': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 197,
#     'ymin': 125,
#     'xmax': 626,
#     'ymax': 547}]},
#  'cju6z2616wqbk07555bvnuyr1': {'height': 531,
#   'width': 554,
#   'bbox': [{'label': 'polyp',
#     'xmin': 268,
#     'ymin': 265,
#     'xmax': 435,
#     'ymax': 485}]},
#  'cju6z600qwh4z081700qimgl9': {'height': 530,
#   'width': 612,
#   'bbox': [{'label': 'polyp',
#     'xmin': 394,
#     'ymin': 276,
#     'xmax': 529,
#     'ymax': 432}]},
#  'cju6z7e4bwgdd0987ogkzq9kt': {'height': 528,
#   'width': 623,
#   'bbox': [{'label': 'polyp',
#     'xmin': 307,
#     'ymin': 212,
#     'xmax': 587,
#     'ymax': 504}]},
#  'cju6z9a9kwsl007552s49rx6i': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 293,
#     'ymin': 224,
#     'xmax': 353,
#     'ymax': 281},
#    {'label': 'polyp', 'xmin': 126, 'ymin': 312, 'xmax': 407, 'ymax': 528}]},
#  'cju76erapykj30871x5eaxh4q': {'height': 529,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 336,
#     'ymin': 90,
#     'xmax': 613,
#     'ymax': 435}]},
#  'cju76l27oyrw907551ri2a7fl': {'height': 480,
#   'width': 396,
#   'bbox': [{'label': 'polyp',
#     'xmin': 146,
#     'ymin': 113,
#     'xmax': 367,
#     'ymax': 441}]},
#  'cju76lsehyia10987u54vn8rb': {'height': 546,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 342,
#     'ymin': 145,
#     'xmax': 496,
#     'ymax': 328}]},
#  'cju76o55nymqd0871h31sph9w': {'height': 529,
#   'width': 600,
#   'bbox': [{'label': 'polyp',
#     'xmin': 187,
#     'ymin': 63,
#     'xmax': 230,
#     'ymax': 129}]},
#  'cju77196iyshb0850ycbto50a': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 253,
#     'ymin': 11,
#     'xmax': 610,
#     'ymax': 364}]},
#  'cju772304yw5t0818vbw8kkjf': {'height': 546,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 343,
#     'ymin': 146,
#     'xmax': 494,
#     'ymax': 329}]},
#  'cju5y7buemcw80987p0r30g9f': {'height': 530,
#   'width': 589,
#   'bbox': [{'label': 'polyp',
#     'xmin': 21,
#     'ymin': 179,
#     'xmax': 312,
#     'ymax': 435}]},
#  'cju5y84q3mdv50817eyp82xf3': {'height': 530,
#   'width': 611,
#   'bbox': [{'label': 'polyp',
#     'xmin': 314,
#     'ymin': 230,
#     'xmax': 440,
#     'ymax': 356}]},
#  'cju5yclrymlgj0818k426ud6z': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 359,
#     'ymin': 94,
#     'xmax': 516,
#     'ymax': 341}]},
#  'cju5yeqiwmkgl0801fzv2douc': {'height': 531,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 238,
#     'ymin': 0,
#     'xmax': 496,
#     'ymax': 277},
#    {'label': 'polyp', 'xmin': 401, 'ymin': 308, 'xmax': 530, 'ymax': 494}]},
#  'cju5ygh1zmmdi0755uod5e17i': {'height': 530,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 239,
#     'ymin': 211,
#     'xmax': 451,
#     'ymax': 495}]},
#  'cju5yhgznmkzb0801cji2vi8j': {'height': 529,
#   'width': 568,
#   'bbox': [{'label': 'polyp',
#     'xmin': 285,
#     'ymin': 139,
#     'xmax': 371,
#     'ymax': 277}]},
#  'cju5yimthmlv80850zhoc90c2': {'height': 528,
#   'width': 590,
#   'bbox': [{'label': 'polyp',
#     'xmin': 180,
#     'ymin': 317,
#     'xmax': 347,
#     'ymax': 449}]},
#  'cju5yjq1pmlgc0801z0t24bly': {'height': 530,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 245,
#     'ymin': 228,
#     'xmax': 459,
#     'ymax': 515}]},
#  'cju5ymyd8mmdc0801ry3by1xr': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 508,
#     'ymin': 211,
#     'xmax': 611,
#     'ymax': 376}]},
#  'cju6ur9l9v9jq0755paud9uka': {'height': 529,
#   'width': 561,
#   'bbox': [{'label': 'polyp',
#     'xmin': 216,
#     'ymin': 183,
#     'xmax': 326,
#     'ymax': 306}]},
#  'cju6us80mv1b50871ebyq2wxa': {'height': 530,
#   'width': 562,
#   'bbox': [{'label': 'polyp',
#     'xmin': 435,
#     'ymin': 164,
#     'xmax': 491,
#     'ymax': 258}]},
#  'cju6ut4l8va6y0755tyw3vfqq': {'height': 529,
#   'width': 605,
#   'bbox': [{'label': 'polyp',
#     'xmin': 338,
#     'ymin': 293,
#     'xmax': 450,
#     'ymax': 396}]},
#  'cju6uy20suzbl0987rzuhz7z9': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 208,
#     'ymin': 145,
#     'xmax': 448,
#     'ymax': 470}]},
#  'cju6v1m1xv07w09870ah3njy1': {'height': 530,
#   'width': 565,
#   'bbox': [{'label': 'polyp',
#     'xmin': 202,
#     'ymin': 42,
#     'xmax': 297,
#     'ymax': 138},
#    {'label': 'polyp', 'xmin': 313, 'ymin': 138, 'xmax': 446, 'ymax': 254}]},
#  'cju6v3bb2v7xo085090blubyw': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 227,
#     'ymin': 0,
#     'xmax': 404,
#     'ymax': 154},
#    {'label': 'polyp', 'xmin': 49, 'ymin': 267, 'xmax': 331, 'ymax': 547}]},
#  'cju6v4szov55u0871qmqz3v8n': {'height': 523,
#   'width': 370,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 126,
#     'xmax': 302,
#     'ymax': 510}]},
#  'cju6v5ilsv8hk0850rb5sgh6o': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 329,
#     'ymin': 227,
#     'xmax': 453,
#     'ymax': 342}]},
#  'cju6v6g6kvdw007552x6mb0po': {'height': 530,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 186,
#     'ymin': 306,
#     'xmax': 460,
#     'ymax': 530}]},
#  'cju6vgdmivcvb08018fra5lnv': {'height': 529,
#   'width': 571,
#   'bbox': [{'label': 'polyp',
#     'xmin': 333,
#     'ymin': 62,
#     'xmax': 553,
#     'ymax': 374}]},
#  'cju6vifjlv55z0987un6y4zdo': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 0,
#     'xmax': 519,
#     'ymax': 528}]},
#  'cju6vqarjv7yo0987q4b1btk1': {'height': 529,
#   'width': 584,
#   'bbox': [{'label': 'polyp',
#     'xmin': 335,
#     'ymin': 208,
#     'xmax': 520,
#     'ymax': 459}]},
#  'cju6vrs1ov8cr098788h8gs6j': {'height': 529,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 259,
#     'ymin': 202,
#     'xmax': 431,
#     'ymax': 358}]},
#  'cju6vta3kvazg0817qbeppjtm': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 255,
#     'ymin': 54,
#     'xmax': 576,
#     'ymax': 403}]},
#  'cju6vucxvvlda0755j7msqnya': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 268,
#     'ymin': 109,
#     'xmax': 412,
#     'ymax': 243},
#    {'label': 'polyp', 'xmin': 389, 'ymin': 257, 'xmax': 432, 'ymax': 308}]},
#  'cju6vvb8svhed0801jjcquh5e': {'height': 530,
#   'width': 604,
#   'bbox': [{'label': 'polyp',
#     'xmin': 158,
#     'ymin': 152,
#     'xmax': 223,
#     'ymax': 299}]},
#  'cju6vvxsev9y30987kespucdg': {'height': 475,
#   'width': 620,
#   'bbox': [{'label': 'polyp',
#     'xmin': 351,
#     'ymin': 63,
#     'xmax': 529,
#     'ymax': 234}]},
#  'cju16ach3m1da0993r1dq3sn2': {'height': 528,
#   'width': 616,
#   'bbox': [{'label': 'polyp',
#     'xmin': 78,
#     'ymin': 160,
#     'xmax': 423,
#     'ymax': 499}]},
#  'cju16b6ynq8e40988m8vx0xnj': {'height': 530,
#   'width': 571,
#   'bbox': [{'label': 'polyp',
#     'xmin': 85,
#     'ymin': 61,
#     'xmax': 175,
#     'ymax': 148}]},
#  'cju16d65tzw9d0799ouslsw25': {'height': 530,
#   'width': 481,
#   'bbox': [{'label': 'polyp',
#     'xmin': 245,
#     'ymin': 211,
#     'xmax': 345,
#     'ymax': 369}]},
#  'cju16fpvhzypl0799p9phnlx6': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 254,
#     'ymin': 186,
#     'xmax': 498,
#     'ymax': 417}]},
#  'cju16jgnyzp970878melv7r25': {'height': 529,
#   'width': 560,
#   'bbox': [{'label': 'polyp',
#     'xmin': 260,
#     'ymin': 236,
#     'xmax': 505,
#     'ymax': 463}]},
#  'cju16whaj0e7n0855q7b6cjkm': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 56,
#     'ymin': 12,
#     'xmax': 532,
#     'ymax': 377}]},
#  'cju171py4qiha0835u8sl59ds': {'height': 530,
#   'width': 616,
#   'bbox': [{'label': 'polyp',
#     'xmin': 205,
#     'ymin': 0,
#     'xmax': 616,
#     'ymax': 419}]},
#  'cju175facms5f0993a5tjikvt': {'height': 528,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 182,
#     'xmax': 438,
#     'ymax': 488}]},
#  'cju17bz250pgd0799u1hqkj5u': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 259,
#     'ymin': 8,
#     'xmax': 441,
#     'ymax': 274}]},
#  'cju17g6ykn1cs0993dww6qdi8': {'height': 510,
#   'width': 605,
#   'bbox': [{'label': 'polyp',
#     'xmin': 93,
#     'ymin': 123,
#     'xmax': 508,
#     'ymax': 510}]},
#  'cju17hw9hr9c5098800fu4u8e': {'height': 528,
#   'width': 623,
#   'bbox': [{'label': 'polyp',
#     'xmin': 217,
#     'ymin': 175,
#     'xmax': 340,
#     'ymax': 261}]},
#  'cju17otoe119u0799nqcbl8n1': {'height': 511,
#   'width': 519,
#   'bbox': [{'label': 'polyp',
#     'xmin': 12,
#     'ymin': 57,
#     'xmax': 515,
#     'ymax': 510}]},
#  'cju17r8il13910799dr2wme2e': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 375,
#     'ymin': 203,
#     'xmax': 447,
#     'ymax': 280}]},
#  'cju17x0j4nfc10993y31pvlgs': {'height': 526,
#   'width': 459,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 0,
#     'xmax': 458,
#     'ymax': 525}]},
#  'cju17z0qongpa0993de4boim4': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 330,
#     'ymin': 270,
#     'xmax': 480,
#     'ymax': 431}]},
#  'cju1819curo000988pd5xcqme': {'height': 529,
#   'width': 600,
#   'bbox': [{'label': 'polyp',
#     'xmin': 244,
#     'ymin': 272,
#     'xmax': 475,
#     'ymax': 478}]},
#  'cju183od81ff608017ekzif89': {'height': 511,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 385,
#     'ymin': 179,
#     'xmax': 571,
#     'ymax': 399},
#    {'label': 'polyp', 'xmin': 242, 'ymin': 383, 'xmax': 421, 'ymax': 508}]},
#  'cju1871y11d6r0799k6cw4yze': {'height': 531,
#   'width': 480,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 183,
#     'xmax': 224,
#     'ymax': 421}]},
#  'cju18849rrsgr0988p90hkygb': {'height': 528,
#   'width': 619,
#   'bbox': [{'label': 'polyp',
#     'xmin': 156,
#     'ymin': 122,
#     'xmax': 410,
#     'ymax': 303}]},
#  'cju18gzrq18zw0878wbf4ftw6': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 355,
#     'ymin': 116,
#     'xmax': 593,
#     'ymax': 308}]},
#  'cju18ibp219ub08783i6o98g7': {'height': 528,
#   'width': 615,
#   'bbox': [{'label': 'polyp',
#     'xmin': 455,
#     'ymin': 320,
#     'xmax': 530,
#     'ymax': 432}]},
#  'cju18kevfrojc0835bn90f1in': {'height': 528,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 217,
#     'ymin': 332,
#     'xmax': 435,
#     'ymax': 478}]},
#  'cju1alwgo30z60855fm3y23sm': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 304,
#     'ymin': 63,
#     'xmax': 491,
#     'ymax': 315}]},
#  'cju1amqw6p8pw0993d9gc5crl': {'height': 547,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 350,
#     'ymin': 220,
#     'xmax': 485,
#     'ymax': 310}]},
#  'cju1aqqv02qwz0878a5cyhr67': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 259,
#     'ymin': 291,
#     'xmax': 453,
#     'ymax': 486}]},
#  'cju1ats0y372e08011yazcsxm': {'height': 528,
#   'width': 623,
#   'bbox': [{'label': 'polyp',
#     'xmin': 166,
#     'ymin': 0,
#     'xmax': 374,
#     'ymax': 345}]},
#  'cju1b3zgj3d8e0801kpolea6c': {'height': 528,
#   'width': 601,
#   'bbox': [{'label': 'polyp',
#     'xmin': 107,
#     'ymin': 184,
#     'xmax': 462,
#     'ymax': 433}]},
#  'cju1b75x63ddl0799sdp0i2j3': {'height': 530,
#   'width': 549,
#   'bbox': [{'label': 'polyp',
#     'xmin': 280,
#     'ymin': 144,
#     'xmax': 415,
#     'ymax': 366}]},
#  'cju1bhnfitmge0835ynls0l6b': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 372,
#     'ymin': 226,
#     'xmax': 607,
#     'ymax': 389}]},
#  'cju1bm8063nmh07996rsjjemq': {'height': 530,
#   'width': 607,
#   'bbox': [{'label': 'polyp',
#     'xmin': 206,
#     'ymin': 15,
#     'xmax': 526,
#     'ymax': 366}]},
#  'cju1brhsj3rls0855a1vgdlen': {'height': 530,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 215,
#     'ymin': 214,
#     'xmax': 352,
#     'ymax': 347}]},
#  'cju1c0qb4tzi308355wtsnp0y': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 120,
#     'ymin': 64,
#     'xmax': 581,
#     'ymax': 461}]},
#  'cju1c3218411b08014g9f6gig': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 122,
#     'ymin': 0,
#     'xmax': 515,
#     'ymax': 182}]},
#  'cju1c4fcu40hl07992b8gj0c8': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 291,
#     'ymin': 199,
#     'xmax': 457,
#     'ymax': 358}]},
#  'cju1c6yfz42md08550zgoz3pw': {'height': 530,
#   'width': 536,
#   'bbox': [{'label': 'polyp',
#     'xmin': 99,
#     'ymin': 0,
#     'xmax': 432,
#     'ymax': 279}]},
#  'cju1c8ffau5770835g0g343o8': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 245,
#     'ymin': 283,
#     'xmax': 367,
#     'ymax': 428}]},
#  'cju1cbokpuiw70988j4lq1fpi': {'height': 529,
#   'width': 615,
#   'bbox': [{'label': 'polyp',
#     'xmin': 236,
#     'ymin': 282,
#     'xmax': 368,
#     'ymax': 456}]},
#  'cju1cdxvz48hw0801i0fjwcnk': {'height': 505,
#   'width': 577,
#   'bbox': [{'label': 'polyp',
#     'xmin': 303,
#     'ymin': 226,
#     'xmax': 462,
#     'ymax': 393}]},
#  'cju1cfhyg48bb0799cl5pr2jh': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 314,
#     'ymin': 39,
#     'xmax': 558,
#     'ymax': 362}]},
#  'cju1cnnziug1l0835yh4ropyg': {'height': 531,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 190,
#     'ymin': 158,
#     'xmax': 530,
#     'ymax': 432}]},
#  'cju1cqc7n4gpy0855jt246k68': {'height': 529,
#   'width': 616,
#   'bbox': [{'label': 'polyp',
#     'xmin': 226,
#     'ymin': 352,
#     'xmax': 384,
#     'ymax': 466}]},
#  'cju1csmlc4ht10799b8ymmghg': {'height': 546,
#   'width': 612,
#   'bbox': [{'label': 'polyp',
#     'xmin': 215,
#     'ymin': 88,
#     'xmax': 465,
#     'ymax': 339}]},
#  'cju1cu1u2474n0878tt7v4tdr': {'height': 531,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 462,
#     'ymin': 101,
#     'xmax': 521,
#     'ymax': 197},
#    {'label': 'polyp', 'xmin': 374, 'ymin': 394, 'xmax': 429, 'ymax': 463}]},
#  'cju1cvkfwqrec0993wbp1jlzm': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 240,
#     'ymin': 340,
#     'xmax': 384,
#     'ymax': 474}]},
#  'cju1cyjb5qtie0993njqne9m3': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 156,
#     'ymin': 4,
#     'xmax': 625,
#     'ymax': 457}]},
#  'cju1d31sp4d4k0878r3fr02ul': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 266,
#     'ymin': 136,
#     'xmax': 458,
#     'ymax': 329}]},
#  'cju1d50a94qf50855wsowacrc': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 357,
#     'ymin': 368,
#     'xmax': 540,
#     'ymax': 530}]},
#  'cju1d96gsv62d09881b3wecw2': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 267,
#     'ymin': 0,
#     'xmax': 621,
#     'ymax': 425}]},
#  'cju1ddr6p4k5z08780uuuzit2': {'height': 531,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 329,
#     'ymin': 168,
#     'xmax': 415,
#     'ymax': 316}]},
#  'cju1dfeupuzlw0835gnxip369': {'height': 1070,
#   'width': 1348,
#   'bbox': [{'label': 'polyp',
#     'xmin': 202,
#     'ymin': 405,
#     'xmax': 557,
#     'ymax': 771}]},
#  'cju1dg44i4z3w0801nyz4p6zf': {'height': 528,
#   'width': 623,
#   'bbox': [{'label': 'polyp',
#     'xmin': 250,
#     'ymin': 352,
#     'xmax': 281,
#     'ymax': 499}]},
#  'cju1dhfok4mhe0878jlgrag0h': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 201,
#     'ymin': 168,
#     'xmax': 347,
#     'ymax': 364}]},
#  'cju1djtprvd7b0988thwwrg09': {'height': 529,
#   'width': 590,
#   'bbox': [{'label': 'polyp',
#     'xmin': 394,
#     'ymin': 274,
#     'xmax': 528,
#     'ymax': 477}]},
#  'cju1dnz61vfp40988e78bkjga': {'height': 547,
#   'width': 627,
#   'bbox': [{'label': 'polyp',
#     'xmin': 377,
#     'ymin': 20,
#     'xmax': 534,
#     'ymax': 238}]},
#  'cju1dq3x1vgx109889c7wyirg': {'height': 513,
#   'width': 617,
#   'bbox': [{'label': 'polyp',
#     'xmin': 191,
#     'ymin': 101,
#     'xmax': 387,
#     'ymax': 350}]},
#  'cju1drnhbrb9409935wi7vkhg': {'height': 529,
#   'width': 619,
#   'bbox': [{'label': 'polyp',
#     'xmin': 107,
#     'ymin': 48,
#     'xmax': 610,
#     'ymax': 529}]},
#  'cju1efbr0rqxz09931z0lf4vf': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 349,
#     'ymin': 100,
#     'xmax': 509,
#     'ymax': 262}]},
#  'cju1egh885m1l0855ci1lt37c': {'height': 531,
#   'width': 566,
#   'bbox': [{'label': 'polyp',
#     'xmin': 191,
#     'ymin': 321,
#     'xmax': 277,
#     'ymax': 451}]},
#  'cju1egx9pvz2n0988eoy8jp23': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 299,
#     'ymin': 344,
#     'xmax': 372,
#     'ymax': 438}]},
#  'cju1ejj7dvqfa0835ra184v5m': {'height': 547,
#   'width': 619,
#   'bbox': [{'label': 'polyp',
#     'xmin': 272,
#     'ymin': 94,
#     'xmax': 559,
#     'ymax': 425}]},
#  'cju1erep75us208553i4ofwwe': {'height': 547,
#   'width': 613,
#   'bbox': [{'label': 'polyp',
#     'xmin': 106,
#     'ymin': 213,
#     'xmax': 418,
#     'ymax': 516}]},
#  'cju1euant5l960878iqj5vvto': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 415,
#     'ymin': 262,
#     'xmax': 558,
#     'ymax': 448}]},
#  'cju1euuc65wm00799m4sjdnnn': {'height': 530,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 164,
#     'ymin': 194,
#     'xmax': 291,
#     'ymax': 322}]},
#  'cju1ewnoh5z030855vpex9uzt': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 277,
#     'ymin': 109,
#     'xmax': 528,
#     'ymax': 331}]},
#  'cju1expq45zst0855rjqwwj4m': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 272,
#     'ymin': 66,
#     'xmax': 598,
#     'ymax': 442}]},
#  'cju1f320ewfyu0988ndz6blh5': {'height': 530,
#   'width': 571,
#   'bbox': [{'label': 'polyp',
#     'xmin': 171,
#     'ymin': 299,
#     'xmax': 477,
#     'ymax': 513}]},
#  'cju1f5x1164xv08555654c24r': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 457,
#     'ymin': 160,
#     'xmax': 622,
#     'ymax': 530}]},
#  'cju1f79yhsb5w0993txub59ol': {'height': 528,
#   'width': 623,
#   'bbox': [{'label': 'polyp',
#     'xmin': 443,
#     'ymin': 296,
#     'xmax': 514,
#     'ymax': 366}]},
#  'cju1f8w0t65en0799m9oacq0q': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 345,
#     'ymin': 79,
#     'xmax': 532,
#     'ymax': 358}]},
#  'cju1fb9236a110801yvg0fwju': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 24,
#     'ymin': 67,
#     'xmax': 406,
#     'ymax': 547}]},
#  'cju1ffnjn6ctm08015perkg37': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 331,
#     'ymin': 26,
#     'xmax': 611,
#     'ymax': 410}]},
#  'cju1fj6axwfp30835ukhuzhw9': {'height': 547,
#   'width': 576,
#   'bbox': [{'label': 'polyp',
#     'xmin': 279,
#     'ymin': 8,
#     'xmax': 576,
#     'ymax': 378}]},
#  'cju1fjsb4sipq09931lvd8e41': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 201,
#     'ymin': 370,
#     'xmax': 388,
#     'ymax': 528}]},
#  'cju1fm3id6gl50801r3fok20c': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 278,
#     'ymin': 204,
#     'xmax': 390,
#     'ymax': 305}]},
#  'cju1fmsyf6gxb0801cimx2gle': {'height': 531,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 265,
#     'ymin': 316,
#     'xmax': 467,
#     'ymax': 486}]},
#  'cju1fr4etsmrr09933u4t4aql': {'height': 521,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 228,
#     'ymin': 166,
#     'xmax': 543,
#     'ymax': 521}]},
#  'cju1ftaji6isw0855108yqcse': {'height': 502,
#   'width': 562,
#   'bbox': [{'label': 'polyp',
#     'xmin': 287,
#     'ymin': 126,
#     'xmax': 529,
#     'ymax': 350}]},
#  'cju1fuoa4wmc50835qfd11sp9': {'height': 528,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 489,
#     'ymin': 146,
#     'xmax': 621,
#     'ymax': 407}]},
#  'cju1g20bdwq6u0835e16xugcd': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 278,
#     'ymin': 120,
#     'xmax': 510,
#     'ymax': 478}]},
#  'cju1g4nsb6ngy0799l4ezm8ab': {'height': 529,
#   'width': 568,
#   'bbox': [{'label': 'polyp',
#     'xmin': 229,
#     'ymin': 248,
#     'xmax': 434,
#     'ymax': 440}]},
#  'cju1gghyjwxt80835vx0wgxw0': {'height': 529,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 159,
#     'ymin': 127,
#     'xmax': 493,
#     'ymax': 416}]},
#  'cju1gi7jlwyld0835cdf6g6qz': {'height': 529,
#   'width': 611,
#   'bbox': [{'label': 'polyp',
#     'xmin': 212,
#     'ymin': 137,
#     'xmax': 366,
#     'ymax': 271}]},
#  'cju1gkndf6yi10801o1qnje19': {'height': 528,
#   'width': 623,
#   'bbox': [{'label': 'polyp',
#     'xmin': 35,
#     'ymin': 203,
#     'xmax': 289,
#     'ymax': 404}]},
#  'cju1gv7106qd008784gk603mg': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 377,
#     'ymin': 14,
#     'xmax': 603,
#     'ymax': 317}]},
#  'cju1h5w4wxajx0835mc954kxy': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 151,
#     'ymin': 100,
#     'xmax': 320,
#     'ymax': 336}]},
#  'cju1h89h6xbnx08352k2790o9': {'height': 531,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 178,
#     'ymin': 227,
#     'xmax': 359,
#     'ymax': 410}]},
#  'cju1haab178i70799tk9z8y8x': {'height': 531,
#   'width': 525,
#   'bbox': [{'label': 'polyp',
#     'xmin': 213,
#     'ymin': 270,
#     'xmax': 406,
#     'ymax': 483}]},
#  'cju1hhj6mxfp90835n3wofrap': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 229,
#     'ymin': 117,
#     'xmax': 328,
#     'ymax': 300}]},
#  'cju1hirfi7ekp0855q0vgm9qq': {'height': 529,
#   'width': 605,
#   'bbox': [{'label': 'polyp',
#     'xmin': 253,
#     'ymin': 222,
#     'xmax': 390,
#     'ymax': 369}]},
#  'cju1hmff8tkp809931jps6fbr': {'height': 530,
#   'width': 587,
#   'bbox': [{'label': 'polyp',
#     'xmin': 137,
#     'ymin': 148,
#     'xmax': 584,
#     'ymax': 530}]},
#  'cju1hp9i2xu8e0988u2dazk7m': {'height': 531,
#   'width': 490,
#   'bbox': [{'label': 'polyp',
#     'xmin': 244,
#     'ymin': 103,
#     'xmax': 466,
#     'ymax': 314}]},
#  'cju1hyolc7aqu0878rrkfn1lr': {'height': 1070,
#   'width': 1348,
#   'bbox': [{'label': 'polyp',
#     'xmin': 121,
#     'ymin': 256,
#     'xmax': 503,
#     'ymax': 650}]},
#  'cju2hdr06v2bq0799mbm3bks1': {'height': 530,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 341,
#     'ymin': 8,
#     'xmax': 621,
#     'ymax': 415}]},
#  'cju2hewssldzx0835ep795xu0': {'height': 530,
#   'width': 576,
#   'bbox': [{'label': 'polyp',
#     'xmin': 345,
#     'ymin': 201,
#     'xmax': 465,
#     'ymax': 351}]},
#  'cju2hfqnmhisa0993gpleeldd': {'height': 530,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 244,
#     'ymin': 231,
#     'xmax': 317,
#     'ymax': 310},
#    {'label': 'polyp', 'xmin': 428, 'ymin': 391, 'xmax': 474, 'ymax': 469}]},
#  'cju2hgsptlfam0835o3b59h1o': {'height': 528,
#   'width': 530,
#   'bbox': [{'label': 'polyp',
#     'xmin': 268,
#     'ymin': 263,
#     'xmax': 357,
#     'ymax': 372}]},
#  'cju2hjrqcvi2j0801bx1i6gxg': {'height': 531,
#   'width': 599,
#   'bbox': [{'label': 'polyp',
#     'xmin': 261,
#     'ymin': 61,
#     'xmax': 308,
#     'ymax': 108},
#    {'label': 'polyp', 'xmin': 312, 'ymin': 372, 'xmax': 388, 'ymax': 435}]},
#  'cju2hlm19vjjf0801o69qnber': {'height': 530,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 50,
#     'ymin': 47,
#     'xmax': 274,
#     'ymax': 322}]},
#  'cju2hos57llxm08359g92p6jj': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 350,
#     'ymin': 130,
#     'xmax': 565,
#     'ymax': 414}]},
#  'cju2hqt33lmra0988fr5ijv8j': {'height': 528,
#   'width': 602,
#   'bbox': [{'label': 'polyp',
#     'xmin': 249,
#     'ymin': 226,
#     'xmax': 464,
#     'ymax': 522}]},
#  'cju2htabevq9108015qjei0x7': {'height': 487,
#   'width': 332,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 37,
#     'xmax': 300,
#     'ymax': 415}]},
#  'cju2hugv9vget0799hhk7ksvg': {'height': 529,
#   'width': 613,
#   'bbox': [{'label': 'polyp',
#     'xmin': 305,
#     'ymin': 150,
#     'xmax': 391,
#     'ymax': 232}]},
#  'cju2hw5gjlr5h0988so2qqres': {'height': 530,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 170,
#     'ymin': 127,
#     'xmax': 454,
#     'ymax': 421}]},
#  'cju2hx006vidl0799igm81vmh': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 337,
#     'ymin': 152,
#     'xmax': 446,
#     'ymax': 259}]},
#  'cju2i3hzclw3o0988rrgh911i': {'height': 531,
#   'width': 598,
#   'bbox': [{'label': 'polyp',
#     'xmin': 67,
#     'ymin': 144,
#     'xmax': 452,
#     'ymax': 531}]},
#  'cju2i6acqvo6l0799u20fift8': {'height': 546,
#   'width': 623,
#   'bbox': [{'label': 'polyp',
#     'xmin': 160,
#     'ymin': 180,
#     'xmax': 392,
#     'ymax': 477}]},
#  'cju2i8br1vqtd08784u6vmcjk': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 202,
#     'ymin': 279,
#     'xmax': 552,
#     'ymax': 523}]},
#  'cju2iatlki5u309930zmgkv6h': {'height': 522,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 297,
#     'ymin': 105,
#     'xmax': 613,
#     'ymax': 522}]},
#  'cju2igw4gvxds0878808qj398': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 0,
#     'xmax': 535,
#     'ymax': 545}]},
#  'cju2ij9uiic2l09933ljiv6gm': {'height': 530,
#   'width': 617,
#   'bbox': [{'label': 'polyp',
#     'xmin': 185,
#     'ymin': 248,
#     'xmax': 385,
#     'ymax': 371}]},
#  'cju2lberzkdzm09938cl40pog': {'height': 528,
#   'width': 605,
#   'bbox': [{'label': 'polyp',
#     'xmin': 63,
#     'ymin': 192,
#     'xmax': 461,
#     'ymax': 457}]},
#  'cju2lcyfgkf5809932fn9gucn': {'height': 530,
#   'width': 571,
#   'bbox': [{'label': 'polyp',
#     'xmin': 218,
#     'ymin': 142,
#     'xmax': 394,
#     'ymax': 290}]},
#  'cju2lejzcy4pc0878c9rlonot': {'height': 530,
#   'width': 571,
#   'bbox': [{'label': 'polyp',
#     'xmin': 208,
#     'ymin': 228,
#     'xmax': 554,
#     'ymax': 499}]},
#  'cju2lyynuymli0855g7fxgbhe': {'height': 519,
#   'width': 612,
#   'bbox': [{'label': 'polyp',
#     'xmin': 274,
#     'ymin': 172,
#     'xmax': 417,
#     'ymax': 329}]},
#  'cju2lz8vqktne0993fuym6drw': {'height': 531,
#   'width': 613,
#   'bbox': [{'label': 'polyp',
#     'xmin': 244,
#     'ymin': 339,
#     'xmax': 418,
#     'ymax': 498}]},
#  'cju2m56cryvqd0801gtn2yp8t': {'height': 546,
#   'width': 616,
#   'bbox': [{'label': 'polyp',
#     'xmin': 61,
#     'ymin': 169,
#     'xmax': 192,
#     'ymax': 310}]},
#  'cju2m71z2ywwv080131bcrsd3': {'height': 531,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 194,
#     'ymin': 283,
#     'xmax': 382,
#     'ymax': 492}]},
#  'cju2mfjndoz700988b9lc3zeq': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 277,
#     'ymin': 99,
#     'xmax': 489,
#     'ymax': 321}]},
#  'cju2mh8t6p07008350e01tx2a': {'height': 528,
#   'width': 588,
#   'bbox': [{'label': 'polyp',
#     'xmin': 250,
#     'ymin': 158,
#     'xmax': 403,
#     'ymax': 334}]},
#  'cju2nbdpmlmcj0993s1cht0dz': {'height': 530,
#   'width': 584,
#   'bbox': [{'label': 'polyp',
#     'xmin': 172,
#     'ymin': 169,
#     'xmax': 538,
#     'ymax': 500}]},
#  'cju2nd7l7z98o0799gfjvyfmw': {'height': 1070,
#   'width': 1348,
#   'bbox': [{'label': 'polyp',
#     'xmin': 546,
#     'ymin': 427,
#     'xmax': 1132,
#     'ymax': 966}]},
#  'cju2nfnvxzdkd0878399axlco': {'height': 546,
#   'width': 598,
#   'bbox': [{'label': 'polyp',
#     'xmin': 64,
#     'ymin': 168,
#     'xmax': 375,
#     'ymax': 369}]},
#  'cju2nguelpmlj0835rojdn097': {'height': 529,
#   'width': 591,
#   'bbox': [{'label': 'polyp',
#     'xmin': 228,
#     'ymin': 237,
#     'xmax': 483,
#     'ymax': 524}]},
#  'cju2nnqrqzp580855z8mhzgd6': {'height': 518,
#   'width': 569,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 0,
#     'xmax': 568,
#     'ymax': 517}]},
#  'cju2np2k9zi3v079992ypxqkn': {'height': 531,
#   'width': 603,
#   'bbox': [{'label': 'polyp',
#     'xmin': 202,
#     'ymin': 254,
#     'xmax': 472,
#     'ymax': 466}]},
#  'cju2nqapmzvk20801f9us40dx': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 41,
#     'ymin': 117,
#     'xmax': 245,
#     'ymax': 362},
#    {'label': 'polyp', 'xmin': 255, 'ymin': 453, 'xmax': 376, 'ymax': 547}]},
#  'cju2nsmwjlzyl0993jl80chvz': {'height': 547,
#   'width': 625,
#   'bbox': [{'label': 'polyp',
#     'xmin': 217,
#     'ymin': 233,
#     'xmax': 365,
#     'ymax': 381}]},
#  'cju2ntxtdzlvu0799xl3j9pan': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 332,
#     'ymin': 357,
#     'xmax': 484,
#     'ymax': 462}]},
#  'cju2nyc5f02m40801ojqbtiea': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 228,
#     'ymin': 326,
#     'xmax': 441,
#     'ymax': 531}]},
#  'cju2oi8sq0i2y0801mektzvw8': {'height': 1070,
#   'width': 1348,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 0,
#     'xmax': 1347,
#     'ymax': 1069}]},
#  'cju2omjpeqj5a0988pjdlb8l1': {'height': 530,
#   'width': 566,
#   'bbox': [{'label': 'polyp',
#     'xmin': 20,
#     'ymin': 135,
#     'xmax': 346,
#     'ymax': 513}]},
#  'cju2oo0wh0bqy0878biujeyhe': {'height': 530,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 286,
#     'ymin': 167,
#     'xmax': 481,
#     'ymax': 360}]},
#  'cju2oq5570avm079959o20op1': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 185,
#     'ymin': 329,
#     'xmax': 581,
#     'ymax': 547}]},
#  'cju2osuru0ki00855txo0n3uu': {'height': 528,
#   'width': 594,
#   'bbox': [{'label': 'polyp',
#     'xmin': 100,
#     'ymin': 33,
#     'xmax': 370,
#     'ymax': 314}]},
#  'cju2otvvv0l7z0855x7we8cb0': {'height': 531,
#   'width': 571,
#   'bbox': [{'label': 'polyp',
#     'xmin': 98,
#     'ymin': 348,
#     'xmax': 305,
#     'ymax': 521}]},
#  'cju2ouil2mssu0993hvxsed6d': {'height': 511,
#   'width': 605,
#   'bbox': [{'label': 'polyp',
#     'xmin': 246,
#     'ymin': 243,
#     'xmax': 361,
#     'ymax': 360}]},
#  'cju2p0eveqtdc0835gpi3p93i': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 146,
#     'ymin': 213,
#     'xmax': 372,
#     'ymax': 459}]},
#  'cju2p4ddkmzxj0993p94o62av': {'height': 529,
#   'width': 592,
#   'bbox': [{'label': 'polyp',
#     'xmin': 247,
#     'ymin': 272,
#     'xmax': 428,
#     'ymax': 466}]},
#  'cju2p91qir00k08350ddfif0w': {'height': 1070,
#   'width': 1348,
#   'bbox': [{'label': 'polyp',
#     'xmin': 348,
#     'ymin': 385,
#     'xmax': 772,
#     'ymax': 648}]},
#  'cju2pag1f0s4r0878h52uq83s': {'height': 530,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 164,
#     'ymin': 286,
#     'xmax': 309,
#     'ymax': 445}]},
#  'cju2phaksnahz0993yxogjcpv': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 60,
#     'ymin': 253,
#     'xmax': 191,
#     'ymax': 436}]},
#  'cju2pjb9v0ywn0878j5g5n69j': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 248,
#     'ymin': 127,
#     'xmax': 423,
#     'ymax': 359}]},
#  'cju2pkwt3r8b90988v2ywq1px': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 80,
#     'ymin': 134,
#     'xmax': 267,
#     'ymax': 298}]},
#  'cju2qdj95ru8g09886gfi9rsz': {'height': 531,
#   'width': 571,
#   'bbox': [{'label': 'polyp',
#     'xmin': 59,
#     'ymin': 132,
#     'xmax': 557,
#     'ymax': 531}]},
#  'cju2qfie4rvz508357kad9z5o': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 152,
#     'ymin': 82,
#     'xmax': 332,
#     'ymax': 394}]},
#  'cju2qh5le1ock0878oahaql7d': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 306,
#     'ymin': 205,
#     'xmax': 543,
#     'ymax': 503}]},
#  'cju2qn2fzs1vy0988l243cvzy': {'height': 547,
#   'width': 597,
#   'bbox': [{'label': 'polyp',
#     'xmin': 203,
#     'ymin': 210,
#     'xmax': 533,
#     'ymax': 524}]},
#  'cju2qozsk20cq0855ugrg3cri': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 370,
#     'ymin': 184,
#     'xmax': 580,
#     'ymax': 451}]},
#  'cju2qqn5ys4uo0988ewrt2ip2': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 53,
#     'ymin': 0,
#     'xmax': 554,
#     'ymax': 515}]},
#  'cju2qs32r1vys07999conmbvx': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 379,
#     'ymin': 145,
#     'xmax': 457,
#     'ymax': 248}]},
#  'cju2qtee81yd708787bsjr75d': {'height': 530,
#   'width': 511,
#   'bbox': [{'label': 'polyp',
#     'xmin': 121,
#     'ymin': 252,
#     'xmax': 340,
#     'ymax': 446}]},
#  'cju2qu37qobl50993aw7ghcfq': {'height': 528,
#   'width': 543,
#   'bbox': [{'label': 'polyp',
#     'xmin': 188,
#     'ymin': 198,
#     'xmax': 343,
#     'ymax': 323}]},
#  'cju2qvuj1s9ok0835tp2k4ozh': {'height': 531,
#   'width': 605,
#   'bbox': [{'label': 'polyp',
#     'xmin': 203,
#     'ymin': 120,
#     'xmax': 592,
#     'ymax': 530}]},
#  'cju2qxxko229x08786gvxxhur': {'height': 530,
#   'width': 484,
#   'bbox': [{'label': 'polyp',
#     'xmin': 80,
#     'ymin': 12,
#     'xmax': 420,
#     'ymax': 424}]},
#  'cju2qz06823a40878ojcz9ccx': {'height': 530,
#   'width': 603,
#   'bbox': [{'label': 'polyp',
#     'xmin': 265,
#     'ymin': 158,
#     'xmax': 518,
#     'ymax': 362}]},
#  'cju2r11x7sdgx0988o8ule0wl': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 308,
#     'ymin': 222,
#     'xmax': 595,
#     'ymax': 466}]},
#  'cju2r6mt2om21099352pny5gw': {'height': 528,
#   'width': 608,
#   'bbox': [{'label': 'polyp',
#     'xmin': 188,
#     'ymin': 0,
#     'xmax': 528,
#     'ymax': 388}]},
#  'cju2r7h21sj9608354gzks3ae': {'height': 530,
#   'width': 614,
#   'bbox': [{'label': 'polyp',
#     'xmin': 263,
#     'ymin': 305,
#     'xmax': 401,
#     'ymax': 403}]},
#  'cju2r91dg2k090801bh0xzbxk': {'height': 1070,
#   'width': 1348,
# ...
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 332,
#     'ymin': 3,
#     'xmax': 450,
#     'ymax': 107}]},
#  'cju8aw9n1qyg10801jkjlmors': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 258,
#     'ymin': 109,
#     'xmax': 575,
#     'ymax': 493}]},
#  'cju8axq24r4an0755yhv9d4ly': {'height': 530,
#   'width': 603,
#   'bbox': [{'label': 'polyp',
#     'xmin': 380,
#     'ymin': 163,
#     'xmax': 510,
#     'ymax': 281}]},
#  'cju8ayeq7r1fb0818z1junacy': {'height': 528,
#   'width': 602,
#   'bbox': [{'label': 'polyp',
#     'xmin': 298,
#     'ymin': 218,
#     'xmax': 423,
#     'ymax': 366}]},
#  'cju8azmhcr66e0755t61atz72': {'height': 531,
#   'width': 548,
#   'bbox': [{'label': 'polyp',
#     'xmin': 236,
#     'ymin': 132,
#     'xmax': 462,
#     'ymax': 440}]},
#  'cju8b0jr0r2oi0801jiquetd5': {'height': 528,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 390,
#     'ymin': 285,
#     'xmax': 537,
#     'ymax': 464}]},
#  'cju8b1v3br45u087189kku66u': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 250,
#     'ymin': 187,
#     'xmax': 543,
#     'ymax': 546}]},
#  'cju8b3ka8r64u0801fh18hk7l': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 59,
#     'ymin': 263,
#     'xmax': 170,
#     'ymax': 409}]},
#  'cju8b4ja9r2s808509d45ma86': {'height': 529,
#   'width': 623,
#   'bbox': [{'label': 'polyp',
#     'xmin': 80,
#     'ymin': 8,
#     'xmax': 358,
#     'ymax': 372}]},
#  'cju8b542nr81x0871uxnkm9ih': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 243,
#     'ymin': 313,
#     'xmax': 349,
#     'ymax': 397}]},
#  'cju8b5p40r2c60987ofa0mu03': {'height': 531,
#   'width': 598,
#   'bbox': [{'label': 'polyp',
#     'xmin': 185,
#     'ymin': 254,
#     'xmax': 338,
#     'ymax': 386}]},
#  'cju8b6rp0r5st0850184f79xt': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 309,
#     'ymin': 82,
#     'xmax': 625,
#     'ymax': 507}]},
#  'cju8b7aqtr4a00987coba14b7': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 187,
#     'ymin': 17,
#     'xmax': 336,
#     'ymax': 142}]},
#  'cju8b8yair65w09878pyqtr96': {'height': 529,
#   'width': 520,
#   'bbox': [{'label': 'polyp',
#     'xmin': 304,
#     'ymin': 209,
#     'xmax': 484,
#     'ymax': 529}]},
#  'cju8bafgqrf4x0818twisk3ea': {'height': 530,
#   'width': 531,
#   'bbox': [{'label': 'polyp',
#     'xmin': 112,
#     'ymin': 141,
#     'xmax': 393,
#     'ymax': 407}]},
#  'cju8bbznkrf5g0871jncffynk': {'height': 531,
#   'width': 619,
#   'bbox': [{'label': 'polyp',
#     'xmin': 108,
#     'ymin': 149,
#     'xmax': 416,
#     'ymax': 529}]},
#  'cju8bff9nrfi10850fmfzbf8v': {'height': 529,
#   'width': 437,
#   'bbox': [{'label': 'polyp',
#     'xmin': 140,
#     'ymin': 274,
#     'xmax': 317,
#     'ymax': 470}]},
#  'cju8bgdmqrksy0801tozdmraa': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 290,
#     'ymin': 35,
#     'xmax': 438,
#     'ymax': 158}]},
#  'cju8bh8surexp0987o5pzklk1': {'height': 506,
#   'width': 577,
#   'bbox': [{'label': 'polyp',
#     'xmin': 169,
#     'ymin': 122,
#     'xmax': 465,
#     'ymax': 421}]},
#  'cju8bi8q7rlmn0871abc5ch8k': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 321,
#     'ymin': 84,
#     'xmax': 498,
#     'ymax': 242}]},
#  'cju8bk8oirjhw0817hgkua2w8': {'height': 509,
#   'width': 575,
#   'bbox': [{'label': 'polyp',
#     'xmin': 62,
#     'ymin': 44,
#     'xmax': 380,
#     'ymax': 479}]},
#  'cju8bljw9rqk20801kr54akrl': {'height': 529,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 140,
#     'ymin': 52,
#     'xmax': 479,
#     'ymax': 436}]},
#  'cju8bm24yrrdp081829mbo8ic': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 284,
#     'ymin': 220,
#     'xmax': 449,
#     'ymax': 442}]},
#  'cju8bn7m2rmm70817hgxpb1uq': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 221,
#     'ymin': 130,
#     'xmax': 597,
#     'ymax': 462}]},
#  'cju8bop5jrsid08716i24fqda': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 325,
#     'ymin': 172,
#     'xmax': 510,
#     'ymax': 347}]},
#  'cju8bpctzrqkr0850zeldv9kt': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 221,
#     'ymin': 82,
#     'xmax': 434,
#     'ymax': 256}]},
#  'cju8bqxxurs6i0850mu7mtef9': {'height': 528,
#   'width': 600,
#   'bbox': [{'label': 'polyp',
#     'xmin': 359,
#     'ymin': 97,
#     'xmax': 589,
#     'ymax': 343}]},
#  'cju8brv16rx7f0818uf5n89pv': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 403,
#     'ymin': 277,
#     'xmax': 518,
#     'ymax': 381}]},
#  'cju8bssulrrcy0987h1vq5060': {'height': 531,
#   'width': 548,
#   'bbox': [{'label': 'polyp',
#     'xmin': 80,
#     'ymin': 312,
#     'xmax': 375,
#     'ymax': 531}]},
#  'cju8buos5rz9b08715lfr0f4f': {'height': 530,
#   'width': 576,
#   'bbox': [{'label': 'polyp',
#     'xmin': 168,
#     'ymin': 43,
#     'xmax': 576,
#     'ymax': 290}]},
#  'cju8bw697rwg308177tg8huas': {'height': 531,
#   'width': 581,
#   'bbox': [{'label': 'polyp',
#     'xmin': 120,
#     'ymin': 7,
#     'xmax': 551,
#     'ymax': 508}]},
#  'cju8bysfgrzkl081786jwac09': {'height': 471,
#   'width': 619,
#   'bbox': [{'label': 'polyp',
#     'xmin': 201,
#     'ymin': 179,
#     'xmax': 484,
#     'ymax': 405}]},
#  'cju8bzzy2s66m08016z6mouqt': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 394,
#     'ymin': 144,
#     'xmax': 562,
#     'ymax': 320}]},
#  'cju8c2rqzs5t80850d0zky5dy': {'height': 490,
#   'width': 615,
#   'bbox': [{'label': 'polyp',
#     'xmin': 196,
#     'ymin': 86,
#     'xmax': 612,
#     'ymax': 477}]},
#  'cju8c3xs7sauj0801ieyzezr5': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 67,
#     'ymin': 72,
#     'xmax': 365,
#     'ymax': 402}]},
#  'cju8c5223s8j80850b4kealt4': {'height': 529,
#   'width': 619,
#   'bbox': [{'label': 'polyp',
#     'xmin': 262,
#     'ymin': 0,
#     'xmax': 454,
#     'ymax': 326}]},
#  'cju8c5mxls96t0850wvkvsity': {'height': 531,
#   'width': 609,
#   'bbox': [{'label': 'polyp',
#     'xmin': 362,
#     'ymin': 256,
#     'xmax': 596,
#     'ymax': 502}]},
#  'cju8c5zcbsdfz0801o5t6jag1': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 438,
#     'ymin': 58,
#     'xmax': 559,
#     'ymax': 169}]},
#  'cju8c6hnxsdvr0801wn0vrsa6': {'height': 531,
#   'width': 617,
#   'bbox': [{'label': 'polyp',
#     'xmin': 327,
#     'ymin': 202,
#     'xmax': 419,
#     'ymax': 261}]},
#  'cju8c82iosagu0817l74s4m5g': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 143,
#     'ymin': 0,
#     'xmax': 546,
#     'ymax': 523}]},
#  'cju8c9akjsdjj0850s67uzlxq': {'height': 518,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 215,
#     'ymin': 152,
#     'xmax': 410,
#     'ymax': 392}]},
#  'cju8ca4geseia0850i2ru11hw': {'height': 529,
#   'width': 617,
#   'bbox': [{'label': 'polyp',
#     'xmin': 350,
#     'ymin': 0,
#     'xmax': 587,
#     'ymax': 244}]},
#  'cju8cattbsivm0818p446wgel': {'height': 531,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 76,
#     'ymin': 66,
#     'xmax': 517,
#     'ymax': 528}]},
#  'cju8cbsyssiqj0871gr4jedjp': {'height': 531,
#   'width': 571,
#   'bbox': [{'label': 'polyp',
#     'xmin': 121,
#     'ymin': 6,
#     'xmax': 353,
#     'ymax': 262}]},
#  'cju8cdeazsm8h0801jxifmzur': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 215,
#     'ymin': 201,
#     'xmax': 445,
#     'ymax': 450}]},
#  'cju8ceacrsqkr0755hdz145es': {'height': 492,
#   'width': 566,
#   'bbox': [{'label': 'polyp',
#     'xmin': 139,
#     'ymin': 65,
#     'xmax': 284,
#     'ymax': 173}]},
#  'cju8chdlqsu620755azjty1tj': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 289,
#     'ymin': 107,
#     'xmax': 474,
#     'ymax': 342}]},
#  'cju8chxndsre008015uisl4si': {'height': 444,
#   'width': 605,
#   'bbox': [{'label': 'polyp',
#     'xmin': 289,
#     'ymin': 83,
#     'xmax': 414,
#     'ymax': 194}]},
#  'cju8cj10qsrau0871o2dr6ai1': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 171,
#     'ymin': 47,
#     'xmax': 352,
#     'ymax': 227}]},
#  'cju8clorgsuwn08714toqb7v6': {'height': 531,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 58,
#     'ymin': 211,
#     'xmax': 271,
#     'ymax': 469}]},
#  'cju8cwy02t9eq08185qn12c02': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 177,
#     'ymin': 0,
#     'xmax': 421,
#     'ymax': 221}]},
#  'cju8czvnztbf40871b4m7t78w': {'height': 546,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 117,
#     'ymin': 207,
#     'xmax': 401,
#     'ymax': 472}]},
#  'cju8d2q30tfhs0801n7lx77xl': {'height': 546,
#   'width': 614,
#   'bbox': [{'label': 'polyp',
#     'xmin': 318,
#     'ymin': 227,
#     'xmax': 595,
#     'ymax': 515}]},
#  'cju8d4jgatgpj0871q2ophhkm': {'height': 531,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 341,
#     'ymin': 126,
#     'xmax': 573,
#     'ymax': 405}]},
#  'cju8dic9mtppa0987swn23wbc': {'height': 531,
#   'width': 611,
#   'bbox': [{'label': 'polyp',
#     'xmin': 20,
#     'ymin': 245,
#     'xmax': 455,
#     'ymax': 531}]},
#  'cju8djdqztu6408506pzhlo18': {'height': 530,
#   'width': 611,
#   'bbox': [{'label': 'polyp',
#     'xmin': 351,
#     'ymin': 27,
#     'xmax': 516,
#     'ymax': 261}]},
#  'cju8dk7eztzup08182yxko5zh': {'height': 528,
#   'width': 623,
#   'bbox': [{'label': 'polyp',
#     'xmin': 179,
#     'ymin': 97,
#     'xmax': 356,
#     'ymax': 238}]},
#  'cju8dm2cau2km0818jsv9eeq2': {'height': 547,
#   'width': 626,
#   'bbox': [{'label': 'polyp',
#     'xmin': 88,
#     'ymin': 316,
#     'xmax': 428,
#     'ymax': 547}]},
#  'cju8dn0c3u2v50801k8rvq02f': {'height': 1070,
#   'width': 1348,
#   'bbox': [{'label': 'polyp',
#     'xmin': 166,
#     'ymin': 263,
#     'xmax': 957,
#     'ymax': 1058}]},
#  'cju8dpa89u6l80818dj6lldh9': {'height': 529,
#   'width': 623,
#   'bbox': [{'label': 'polyp',
#     'xmin': 81,
#     'ymin': 263,
#     'xmax': 361,
#     'ymax': 518}]},
#  'cju8dqkrqu83i0818ev74qpxq': {'height': 1070,
#   'width': 1348,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 1,
#     'xmax': 1345,
#     'ymax': 996}]},
#  'cjyzjzssvd8pq0838f4nolj5l': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 131,
#     'ymin': 82,
#     'xmax': 223,
#     'ymax': 337},
#    {'label': 'polyp', 'xmin': 186, 'ymin': 157, 'xmax': 188, 'ymax': 161}]},
#  'cjyzk8qieoboa0848ogj51wwm': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 51,
#     'ymin': 21,
#     'xmax': 620,
#     'ymax': 531}]},
#  'cjyzkmjy8evns070165gf9dmq': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 166,
#     'ymin': 134,
#     'xmax': 377,
#     'ymax': 387}]},
#  'cjyzkpsbjdsjq07211dfi4sru': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 280,
#     'ymin': 103,
#     'xmax': 458,
#     'ymax': 188}]},
#  'cjyzl833ndne80838pzuq6ila': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 216,
#     'ymin': 50,
#     'xmax': 443,
#     'ymax': 377}]},
#  'cjyzlw7f9faqr070129au64sq': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 212,
#     'ymin': 98,
#     'xmax': 429,
#     'ymax': 343}]},
#  'cjyztzaqtrv430848l8xgcerw': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 248,
#     'ymin': 179,
#     'xmax': 647,
#     'ymax': 504}]},
#  'cjyzu3reghjya0794w7pwoi50': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 344,
#     'ymin': 75,
#     'xmax': 614,
#     'ymax': 365}]},
#  'cjyzu9th0qt4r0a46pyl4zik0': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 52,
#     'ymin': 116,
#     'xmax': 258,
#     'ymax': 341}]},
#  'cjyzufihqquiw0a46jatrbwln': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 226,
#     'ymin': 41,
#     'xmax': 657,
#     'ymax': 557}]},
#  'cjyzuio1qgh040763k56deohv': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 271,
#     'ymin': 218,
#     'xmax': 351,
#     'ymax': 312}]},
#  'cjyzul1qggwwj07216mhiv5sy': {'height': 1072,
#   'width': 1920,
#   'bbox': [{'label': 'polyp',
#     'xmin': 667,
#     'ymin': 413,
#     'xmax': 1007,
#     'ymax': 763}]},
#  'cjyzurzvohqnr0794es1itzek': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 326,
#     'ymin': 145,
#     'xmax': 553,
#     'ymax': 487}]},
#  'cjz14qsk2wci60794un9ozwmw': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 205,
#     'ymin': 198,
#     'xmax': 430,
#     'ymax': 487}]},
#  'ck2395w2mb4vu07480otsu6tw': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 348,
#     'ymin': 273,
#     'xmax': 592,
#     'ymax': 553}]},
#  'ck2bxiswtxuw80838qkisqjwz': {'height': 520,
#   'width': 621,
#   'bbox': [{'label': 'polyp', 'xmin': 0, 'ymin': 7, 'xmax': 557, 'ymax': 494},
#    {'label': 'polyp', 'xmin': 432, 'ymin': 144, 'xmax': 443, 'ymax': 147}]},
#  'ck2bxknhjvs1x0794iogrq49k': {'height': 528,
#   'width': 603,
#   'bbox': [{'label': 'polyp',
#     'xmin': 380,
#     'ymin': 135,
#     'xmax': 568,
#     'ymax': 387},
#    {'label': 'polyp', 'xmin': 329, 'ymin': 207, 'xmax': 372, 'ymax': 263}]},
#  'ck2bxlujamu330725szlc2jdu': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 363,
#     'ymin': 387,
#     'xmax': 508,
#     'ymax': 546}]},
#  'ck2bxpfgxu2mk0748gsh7xelu': {'height': 531,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 388,
#     'ymin': 260,
#     'xmax': 614,
#     'ymax': 496}]},
#  'ck2bxqz3evvg20794iiyv5v2m': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 181,
#     'ymin': 157,
#     'xmax': 406,
#     'ymax': 388}]},
#  'ck2bxskgxxzfv08386xkqtqdy': {'height': 530,
#   'width': 585,
#   'bbox': [{'label': 'polyp',
#     'xmin': 296,
#     'ymin': 0,
#     'xmax': 423,
#     'ymax': 198},
#    {'label': 'polyp', 'xmin': 431, 'ymin': 375, 'xmax': 502, 'ymax': 470}]},
#  'ck2bxw18mmz1k0725litqq2mc': {'height': 528,
#   'width': 600,
#   'bbox': [{'label': 'polyp',
#     'xmin': 16,
#     'ymin': 91,
#     'xmax': 424,
#     'ymax': 428}]},
#  'ck2da7fwcjfis07218r1rvm95': {'height': 576,
#   'width': 720,
#   'bbox': [{'label': 'polyp',
#     'xmin': 320,
#     'ymin': 205,
#     'xmax': 490,
#     'ymax': 338}]},
#  'cju83k8fyjsxr0817d6nxs6r4': {'height': 528,
#   'width': 621,
#   'bbox': [{'label': 'polyp',
#     'xmin': 89,
#     'ymin': 283,
#     'xmax': 382,
#     'ymax': 479}]},
#  'cju843yjskhq30818qre4rwm2': {'height': 437,
#   'width': 547,
#   'bbox': [{'label': 'polyp',
#     'xmin': 334,
#     'ymin': 84,
#     'xmax': 429,
#     'ymax': 299}]},
#  'cju858eswlepn0871pzvdrhj1': {'height': 530,
#   'width': 570,
#   'bbox': [{'label': 'polyp',
#     'xmin': 275,
#     'ymin': 216,
#     'xmax': 570,
#     'ymax': 530}]},
#  'cju85plp7lmkw0850rx42jdpf': {'height': 530,
#   'width': 596,
#   'bbox': [{'label': 'polyp',
#     'xmin': 293,
#     'ymin': 0,
#     'xmax': 596,
#     'ymax': 473}]},
#  'cju87zv8lni0o0850hbbecbq6': {'height': 528,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 297,
#     'ymin': 306,
#     'xmax': 388,
#     'ymax': 380}]},
#  'cju88l66no10s0850rsda7ej1': {'height': 530,
#   'width': 571,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 0,
#     'xmax': 570,
#     'ymax': 529}]},
#  'cju892fesoq2g0801n0e0jyia': {'height': 546,
#   'width': 589,
#   'bbox': [{'label': 'polyp',
#     'xmin': 144,
#     'ymin': 143,
#     'xmax': 529,
#     'ymax': 402}]},
#  'cju8amfdtqi4x09871tygrgqe': {'height': 530,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 209,
#     'ymin': 148,
#     'xmax': 432,
#     'ymax': 427}]},
#  'cju8b2rmgr52s0801p54eyflx': {'height': 530,
#   'width': 587,
#   'bbox': [{'label': 'polyp',
#     'xmin': 172,
#     'ymin': 114,
#     'xmax': 476,
#     'ymax': 364}]},
#  'cju8bj2ssrmlm0871gc2ug2rs': {'height': 449,
#   'width': 469,
#   'bbox': [{'label': 'polyp',
#     'xmin': 274,
#     'ymin': 184,
#     'xmax': 311,
#     'ymax': 222}]},
#  'cju8c1a0ws7o208181c6lbsom': {'height': 546,
#   'width': 625,
#   'bbox': [{'label': 'polyp',
#     'xmin': 138,
#     'ymin': 0,
#     'xmax': 624,
#     'ymax': 341}]},
#  'cju8cgi2kspp308011nxdtjp6': {'height': 530,
#   'width': 619,
#   'bbox': [{'label': 'polyp',
#     'xmin': 373,
#     'ymin': 242,
#     'xmax': 487,
#     'ymax': 357}]},
#  'cju8doa16u5gh0818w1ywda3q': {'height': 529,
#   'width': 622,
#   'bbox': [{'label': 'polyp',
#     'xmin': 0,
#     'ymin': 0,
#     'xmax': 621,
#     'ymax': 528}]}}

# %%
# --------- utilities ---------
IMG_EXTS = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"}

def list_images(d: Path):
    return sorted(p for p in d.iterdir() if p.is_file() and p.suffix.lower() in IMG_EXTS)

def parse_bbox_txt(txt_path: Path | None):
    """Accepts lines like: 'polyp 773 760 1056 904' or '773 760 1056 904'."""
    if not txt_path or not txt_path.exists():
        return np.zeros((0,4), np.float32), np.zeros((0,), np.int64)
    boxes = []
    with txt_path.open("r") as f:
        for line in f:
            parts = line.strip().split()
            if not parts: 
                continue
            if parts[0].isalpha():
                parts = parts[1:]
            if len(parts) < 4:
                continue
            x1, y1, x2, y2 = map(float, parts[:4])
            boxes.append([x1, y1, x2, y2])
    if not boxes:
        return np.zeros((0,4), np.float32), np.zeros((0,), np.int64)
    return np.array(boxes, np.float32), np.zeros((len(boxes),), np.int64)  # class 0 = polyp

def clamp_boxes_xyxy(boxes, w, h):
    if boxes.size == 0:
        return boxes
    b = boxes.copy()
    b[:, [0,2]] = np.clip(b[:, [0,2]], 0, w - 1)
    b[:, [1,3]] = np.clip(b[:, [1,3]], 0, h - 1)
    b[:, [0,2]] = np.sort(b[:, [0,2]], axis=1)
    b[:, [1,3]] = np.sort(b[:, [1,3]], axis=1)
    keep = (b[:, 2] > b[:, 0]) & (b[:, 3] > b[:, 1])
    return b[keep]

def xyxy_to_yolo(boxes_xyxy, w, h):
    if boxes_xyxy.size == 0:
        return np.zeros((0,4), np.float32)
    x1, y1, x2, y2 = [boxes_xyxy[:, i] for i in range(4)]
    bw, bh = (x2 - x1), (y2 - y1)
    cx, cy = x1 + bw/2.0, y1 + bh/2.0
    return np.stack([cx/w, cy/h, bw/w, bh/h], axis=1).astype(np.float32)

def write_yolo_label_file(label_path: Path, rows):
    label_path.parent.mkdir(parents=True, exist_ok=True)
    with label_path.open("w") as f:
        for cls_id, (cx, cy, bw, bh) in rows:
            f.write(f"{cls_id} {cx:.6f} {cy:.6f} {bw:.6f} {bh:.6f}\n")

def index_txts_one_dir(bbox_dir: Path | None):
    if not (bbox_dir and bbox_dir.exists()):
        return {}
    return {p.stem: p for p in bbox_dir.iterdir() if p.is_file() and p.suffix.lower() == ".txt"}

# %%
def generate_yolo_labels_from_json(
    images_dir: Path,
    labels_dict: dict,
    out_labels_dir: Path | None = None,
    prefer_json_dims: bool = True,
    overwrite: bool = True,
    verbose: bool = True,
):
    if not images_dir.exists():
        raise FileNotFoundError(images_dir)

    out_labels_dir = out_labels_dir or (images_dir.parent / f"{images_dir.name}_yolo_labels")
    out_labels_dir.mkdir(parents=True, exist_ok=True)

    imgs = list_images(images_dir)
    total = pos = neg = bad = 0

    for img in imgs:
        stem = img.stem
        dest_lbl = out_labels_dir / f"{stem}.txt"
        if not overwrite and dest_lbl.exists():
            total += 1
            if dest_lbl.stat().st_size > 0: pos += 1
            else: neg += 1
            continue

        entry = labels_dict.get(stem)

        # choose dimensions
        if prefer_json_dims and entry and "width" in entry and "height" in entry:
            W, H = int(entry["width"]), int(entry["height"])
        else:
            im = cv2.imread(str(img))
            if im is None:
                bad += 1
                write_yolo_label_file(dest_lbl, [])
                total += 1; neg += 1
                if verbose: print(f"[WARN] unreadable image: {img}")
                continue
            H, W = im.shape[:2]

        if entry and entry.get("bbox"):
            xyxy = np.array([[b["xmin"], b["ymin"], b["xmax"], b["ymax"]] for b in entry["bbox"]], dtype=np.float32)
            xyxy = clamp_boxes_xyxy(xyxy, W, H)
            yolo = xyxy_to_yolo(xyxy, W, H)
            rows = [(0, t) for t in yolo]  # class 0 = polyp
            write_yolo_label_file(dest_lbl, rows)
            pos += int(len(rows) > 0); neg += int(len(rows) == 0)
        else:
            write_yolo_label_file(dest_lbl, [])
            neg += 1

        total += 1

    if verbose:
        print(f"[{images_dir.name}] → {out_labels_dir}")
        print(f"TOTAL={total}  POS={pos}  NEG={neg}  BAD={bad}")

    return out_labels_dir

# %%
kvasir_yolo_labels_path = generate_yolo_labels_from_json(kvasir_images_path, kvasir_labels)
# Out:
# [images] → ..\data\kvasir-seg\images_yolo_labels
# TOTAL=1000  POS=1000  NEG=0  BAD=0

# %%
kvasir_yolo_labels_path
# Out:
# WindowsPath('../data/kvasir-seg/images_yolo_labels')

# %% [markdown]
# # 2. YOLO Labels for Polyps Data (Each Folder Generated Separately):

# %% [markdown]
# ### 2.A. Generate Dictionary of All Folders and Paths

# %%
train_path = ROOT / "data/detection2/train"
valid_path = ROOT / "data/detection2/valid"
test_path = ROOT / "data/detection2/valid"

def _first_child_startswith(parent: Path, prefix: str, exclude_prefixes=()):
    """Return the first subdir whose name starts with `prefix` (case-insensitive) and
       does NOT start with any of the `exclude_prefixes`."""
    pref = prefix.lower()
    exclude = tuple(ep.lower() for ep in exclude_prefixes)
    for p in sorted(parent.iterdir()):
        if p.is_dir():
            name = p.name.lower()
            if name.startswith(pref) and not any(name.startswith(ep) for ep in exclude):
                return p
    return None

def build_sources_dict_from_schema(split_root: Path):
    """
    Build a dict of {name: {type, images_dir, bbox_dir}} for a split folder.

    - 'single' → top-level images/ (+ bbox/ if exists)
    - 'seqXX'  → seq with images_* and bbox_* (ignoring masks_* and bbox_image_*)
                  -> type='seq_pos' if bbox_* exists, else 'seq_neg'
    - 'seqXX_neg' → negatives: images directly under seq folder, no bbox (type='seq_neg')
    """
    out = {}

    # 1) Top-level single set
    images_dir = split_root / "images_single"
    bbox_dir   = split_root / "bbox"
    if images_dir.exists():
        out["single"] = {
            "type": "single",
            "images_dir": images_dir,
            "bbox_dir": bbox_dir if bbox_dir.exists() else None
        }

    # 2) Sequences (train/valid/test have seq/; test may have seq_test/)
    seq_root = None
    for cand in ("seq", "seq_test"):
        cand_path = split_root / cand
        if cand_path.exists():
            seq_root = cand_path
            break

    if seq_root:
        for seq_dir in sorted([p for p in seq_root.iterdir() if p.is_dir()]):
            name = seq_dir.name
            is_neg = name.lower().endswith("_neg")

            if is_neg:
                # negatives: images directly live in seq_dir; no bbox
                out[name] = {
                    "type": "seq_neg",
                    "images_dir": seq_dir,
                    "bbox_dir": None
                }
            else:
                # positives: look for images_* and bbox_*; ignore masks_* and bbox_image_*
                images_sub = _first_child_startswith(seq_dir, "images")
                # for bbox, exclude 'bbox_image_*'
                bbox_sub   = _first_child_startswith(seq_dir, "bbox", exclude_prefixes=("bbox_image",))

                if images_sub and images_sub.exists():
                    out[name] = {
                        "type": "seq_pos" if (bbox_sub and bbox_sub.exists()) else "seq_neg",
                        "images_dir": images_sub,
                        "bbox_dir": bbox_sub if (bbox_sub and bbox_sub.exists()) else None
                    }
                else:
                    # fallback: treat as negative if no images_* folder
                    out[name] = {
                        "type": "seq_neg",
                        "images_dir": seq_dir,
                        "bbox_dir": None
                    }

    return out

train_sources = build_sources_dict_from_schema(ROOT / "data/detection2/train")
valid_sources = build_sources_dict_from_schema(ROOT / "data/detection2/valid")
test_sources  = build_sources_dict_from_schema(ROOT / "data/detection2/test")

# %%
# print to see
test_sources
# Out:
# {'single': {'type': 'single',
#   'images_dir': WindowsPath('../data/detection2/test/images_single'),
#   'bbox_dir': WindowsPath('../data/detection2/test/bbox')},
#  'seq15': {'type': 'seq_pos',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq15/images_seq15'),
#   'bbox_dir': WindowsPath('../data/detection2/test/seq_test/seq15/bbox_seq15')},
#  'seq15_neg': {'type': 'seq_neg',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq15_neg'),
#   'bbox_dir': None},
#  'seq16': {'type': 'seq_pos',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq16/images_seq16'),
#   'bbox_dir': WindowsPath('../data/detection2/test/seq_test/seq16/bbox_seq16')},
#  'seq16_neg': {'type': 'seq_neg',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq16_neg'),
#   'bbox_dir': None},
#  'seq17': {'type': 'seq_pos',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq17/images_seq17'),
#   'bbox_dir': WindowsPath('../data/detection2/test/seq_test/seq17/bbox_seq17')},
#  'seq17_neg': {'type': 'seq_neg',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq17_neg'),
#   'bbox_dir': None},
#  'seq18': {'type': 'seq_pos',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq18/images_seq18'),
#   'bbox_dir': WindowsPath('../data/detection2/test/seq_test/seq18/bbox_seq18')},
#  'seq18_neg': {'type': 'seq_neg',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq18_neg'),
#   'bbox_dir': None},
#  'seq19': {'type': 'seq_pos',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq19/images_seq19'),
#   'bbox_dir': WindowsPath('../data/detection2/test/seq_test/seq19/bbox_seq19')},
#  'seq19_neg': {'type': 'seq_neg',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq19_neg'),
#   'bbox_dir': None},
#  'seq20': {'type': 'seq_pos',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq20/images_seq20'),
#   'bbox_dir': WindowsPath('../data/detection2/test/seq_test/seq20/bbox_seq20')},
#  'seq20_neg': {'type': 'seq_neg',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq20_neg'),
#   'bbox_dir': None},
#  'seq21': {'type': 'seq_pos',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq21/images_seq21'),
#   'bbox_dir': WindowsPath('../data/detection2/test/seq_test/seq21/bbox_seq21')},
#  'seq21_neg': {'type': 'seq_neg',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq21_neg'),
#   'bbox_dir': None},
#  'seq22': {'type': 'seq_pos',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq22/images_seq22'),
#   'bbox_dir': WindowsPath('../data/detection2/test/seq_test/seq22/bbox_seq22')},
#  'seq22_neg': {'type': 'seq_neg',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq22_neg'),
#   'bbox_dir': None},
#  'seq23': {'type': 'seq_pos',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq23/images_seq23'),
#   'bbox_dir': WindowsPath('../data/detection2/test/seq_test/seq23/bbox_seq23')},
#  'seq23_neg': {'type': 'seq_neg',
#   'images_dir': WindowsPath('../data/detection2/test/seq_test/seq23_neg'),
#   'bbox_dir': None}}

# %% [markdown]
# ### 2.B. PolypGen: Generate YOLO Labels per Folder

# %%
# --------- core ---------
def generate_yolo_labels_for_folder(
    images_dir: Path,
    bbox_dir: Path | None = None,
    out_labels_dir: Path | None = None,
    selection_fn=None,
    overwrite: bool = True,
    verbose: bool = True,
):
    if not images_dir or not images_dir.exists():
        raise FileNotFoundError(f"images_dir not found: {images_dir}")

    out_labels_dir = out_labels_dir or (images_dir.parent / f"{images_dir.name}_yolo_labels")
    out_labels_dir.mkdir(parents=True, exist_ok=True)

    lbl_index = index_txts_one_dir(bbox_dir)
    imgs = list_images(images_dir)
    if selection_fn:
        imgs = selection_fn(imgs)

    total = pos = neg = bad = 0

    for img_path in imgs:
        dest_lbl = out_labels_dir / f"{img_path.stem}.txt"
        if not overwrite and dest_lbl.exists():
            total += 1
            if dest_lbl.stat().st_size > 0: pos += 1
            else: neg += 1
            continue

        im = cv2.imread(str(img_path))
        if im is None:
            bad += 1
            write_yolo_label_file(dest_lbl, [])  # keep pipeline robust
            total += 1; neg += 1
            if verbose: print(f"[WARN] unreadable image: {img_path}")
            continue

        h, w = im.shape[:2]
        lbl_path = lbl_index.get(img_path.stem)
        boxes_xyxy, labels = parse_bbox_txt(lbl_path)
        boxes_xyxy = clamp_boxes_xyxy(boxes_xyxy, w, h)
        yolo_boxes = xyxy_to_yolo(boxes_xyxy, w, h)
        rows = [(int(c), wh) for c, wh in zip(labels.tolist(), yolo_boxes)]

        write_yolo_label_file(dest_lbl, rows)
        total += 1
        if rows: pos += 1
        else:    neg += 1

    if verbose:
        print(f"[{images_dir.name}] → {out_labels_dir}")
        print(f"TOTAL={total}  POS={pos}  NEG={neg}  BAD={bad}")

    return out_labels_dir

# %%
def generate_yolo_labels_for_all_folders(sources_dict, **kwargs):
    if not sources_dict:
        return
    for _, meta in sources_dict.items():
        images_dir = meta["images_dir"]
        bbox_dir   = meta.get("bbox_dir")
        generate_yolo_labels_for_folder(images_dir, bbox_dir, **kwargs)

# Run for each split (skip if None/empty)
for sources in (train_sources, valid_sources, test_sources):
    generate_yolo_labels_for_all_folders(sources, overwrite=True, verbose=True)
# Out:
# [images_single] → ..\data\detection2\train\images_single_yolo_labels
# TOTAL=1105  POS=1013  NEG=92  BAD=0
# [images_seq10] → ..\data\detection2\train\seq\seq10\images_seq10_yolo_labels
# TOTAL=25  POS=7  NEG=18  BAD=0
# [images_seq11] → ..\data\detection2\train\seq\seq11\images_seq11_yolo_labels
# TOTAL=228  POS=136  NEG=92  BAD=0
# [images_seq12] → ..\data\detection2\train\seq\seq12\images_seq12_yolo_labels
# TOTAL=250  POS=250  NEG=0  BAD=0
# [images_seq13] → ..\data\detection2\train\seq\seq13\images_seq13_yolo_labels
# TOTAL=250  POS=199  NEG=51  BAD=0
# [seq16_neg] → ..\data\detection2\train\seq\seq16_neg_yolo_labels
# TOTAL=141  POS=0  NEG=141  BAD=0
# [seq1_neg] → ..\data\detection2\train\seq\seq1_neg_yolo_labels
# TOTAL=315  POS=0  NEG=315  BAD=0
# [images_seq2] → ..\data\detection2\train\seq\seq2\images_seq2_yolo_labels
# TOTAL=63  POS=60  NEG=3  BAD=0
# [seq22_neg] → ..\data\detection2\train\seq\seq22_neg_yolo_labels
# TOTAL=82  POS=0  NEG=82  BAD=0
# [seq2_neg] → ..\data\detection2\train\seq\seq2_neg_yolo_labels
# TOTAL=302  POS=0  NEG=302  BAD=0
# [images_seq3] → ..\data\detection2\train\seq\seq3\images_seq3_yolo_labels
# TOTAL=15  POS=15  NEG=0  BAD=0
# [seq3_neg] → ..\data\detection2\train\seq\seq3_neg_yolo_labels
# TOTAL=40  POS=0  NEG=40  BAD=0
# [images_seq4] → ..\data\detection2\train\seq\seq4\images_seq4_yolo_labels
# TOTAL=48  POS=46  NEG=2  BAD=0
# [seq4_neg] → ..\data\detection2\train\seq\seq4_neg_yolo_labels
# TOTAL=72  POS=0  NEG=72  BAD=0
# [images_seq5] → ..\data\detection2\train\seq\seq5\images_seq5_yolo_labels
# TOTAL=250  POS=199  NEG=51  BAD=0
# [seq5_neg] → ..\data\detection2\train\seq\seq5_neg_yolo_labels
# TOTAL=61  POS=0  NEG=61  BAD=0
# [images_seq6] → ..\data\detection2\train\seq\seq6\images_seq6_yolo_labels
# TOTAL=91  POS=62  NEG=29  BAD=0
# [seq6_neg] → ..\data\detection2\train\seq\seq6_neg_yolo_labels
# TOTAL=90  POS=0  NEG=90  BAD=0
# [seq7_neg] → ..\data\detection2\train\seq\seq7_neg_yolo_labels
# TOTAL=207  POS=0  NEG=207  BAD=0
# [images_seq8] → ..\data\detection2\train\seq\seq8\images_seq8_yolo_labels
# TOTAL=73  POS=54  NEG=19  BAD=0
# [seq8_neg] → ..\data\detection2\train\seq\seq8_neg_yolo_labels
# TOTAL=311  POS=0  NEG=311  BAD=0
# [images_seq9] → ..\data\detection2\train\seq\seq9\images_seq9_yolo_labels
# TOTAL=51  POS=42  NEG=9  BAD=0
# [seq9_neg] → ..\data\detection2\train\seq\seq9_neg_yolo_labels
# TOTAL=99  POS=0  NEG=99  BAD=0
# [images_single] → ..\data\detection2\valid\images_single_yolo_labels
# TOTAL=139  POS=128  NEG=11  BAD=0
# [images_seq14] → ..\data\detection2\valid\seq\seq14\images_seq14_yolo_labels
# TOTAL=249  POS=200  NEG=49  BAD=0
# [seq15_neg] → ..\data\detection2\valid\seq\seq15_neg_yolo_labels
# TOTAL=278  POS=0  NEG=278  BAD=0
# [images_single] → ..\data\detection2\test\images_single_yolo_labels
# TOTAL=229  POS=206  NEG=23  BAD=0
# [images_seq15] → ..\data\detection2\test\seq_test\seq15\images_seq15_yolo_labels
# TOTAL=116  POS=116  NEG=0  BAD=0
# [seq15_neg] → ..\data\detection2\test\seq_test\seq15_neg_yolo_labels
# TOTAL=278  POS=0  NEG=278  BAD=0
# [images_seq16] → ..\data\detection2\test\seq_test\seq16\images_seq16_yolo_labels
# TOTAL=40  POS=33  NEG=7  BAD=0
# [seq16_neg] → ..\data\detection2\test\seq_test\seq16_neg_yolo_labels
# TOTAL=141  POS=0  NEG=141  BAD=0
# [images_seq17] → ..\data\detection2\test\seq_test\seq17\images_seq17_yolo_labels
# TOTAL=63  POS=44  NEG=19  BAD=0
# [seq17_neg] → ..\data\detection2\test\seq_test\seq17_neg_yolo_labels
# TOTAL=130  POS=0  NEG=130  BAD=0
# [images_seq18] → ..\data\detection2\test\seq_test\seq18\images_seq18_yolo_labels
# TOTAL=63  POS=56  NEG=7  BAD=0
# [seq18_neg] → ..\data\detection2\test\seq_test\seq18_neg_yolo_labels
# TOTAL=121  POS=0  NEG=121  BAD=0
# [images_seq19] → ..\data\detection2\test\seq_test\seq19\images_seq19_yolo_labels
# TOTAL=56  POS=55  NEG=1  BAD=0
# [seq19_neg] → ..\data\detection2\test\seq_test\seq19_neg_yolo_labels
# TOTAL=210  POS=0  NEG=210  BAD=0
# [images_seq20] → ..\data\detection2\test\seq_test\seq20\images_seq20_yolo_labels
# TOTAL=52  POS=31  NEG=21  BAD=0
# [seq20_neg] → ..\data\detection2\test\seq_test\seq20_neg_yolo_labels
# TOTAL=191  POS=0  NEG=191  BAD=0
# [images_seq21] → ..\data\detection2\test\seq_test\seq21\images_seq21_yolo_labels
# TOTAL=56  POS=25  NEG=31  BAD=0
# [seq21_neg] → ..\data\detection2\test\seq_test\seq21_neg_yolo_labels
# TOTAL=151  POS=0  NEG=151  BAD=0
# [images_seq22] → ..\data\detection2\test\seq_test\seq22\images_seq22_yolo_labels
# TOTAL=46  POS=44  NEG=2  BAD=0
# [seq22_neg] → ..\data\detection2\test\seq_test\seq22_neg_yolo_labels
# TOTAL=82  POS=0  NEG=82  BAD=0
# [images_seq23] → ..\data\detection2\test\seq_test\seq23\images_seq23_yolo_labels
# TOTAL=56  POS=36  NEG=20  BAD=0
# [seq23_neg] → ..\data\detection2\test\seq_test\seq23_neg_yolo_labels
# TOTAL=150  POS=0  NEG=150  BAD=0

# %% [markdown]
# # 3. Combine Images and YOLO Labels for Training

# %%
#train_list = ['images_single']
train_list = list(train_sources.keys())
val_list = ['single','seq14', 'seq15_neg', 'kvasir_images']

# %%
def _labels_sibling(images_dir: Path) -> Path:
    return images_dir.parent / f"{images_dir.name}_yolo_labels"

def _copy_or_link(src: Path, dst: Path, mode: str = "copy"):
    dst.parent.mkdir(parents=True, exist_ok=True)
    if dst.exists():
        return
    if mode == "hardlink":
        os.link(src, dst)  # same volume only
    elif mode == "symlink":
        os.symlink(src, dst)
    else:
        shutil.copy2(src, dst)

def _ensure_empty(path: Path):
    path.parent.mkdir(parents=True, exist_ok=True)
    if not path.exists():
        path.write_text("")

def _resolve_images_dir(
    key: str,
    sources_dicts: list[dict],           # e.g., [train_sources, valid_sources]
    extra_map: dict[str, Path] | None,   # e.g., {"kvasir_images": ROOT/"data/kvasir-seg/images"}
) -> Path:
    # 1) exact key in any sources dict
    for sd in sources_dicts:
        if sd and key in sd:
            return sd[key]["images_dir"]

    # 2) match by folder name (images_dir.name) or parent folder name (seq14, etc.)
    for sd in sources_dicts:
        if not sd: 
            continue
        for _, meta in sd.items():
            imgd: Path = meta["images_dir"]
            if imgd.name == key or imgd.parent.name == key:
                return imgd

    # 3) fallback: extra map (e.g., Kvasir)
    if extra_map and key in extra_map:
        return extra_map[key]

    raise KeyError(f"Could not resolve images_dir for key='{key}'")

def merge_yolo_split_keys(
    dest_split_root: Path,
    keys: list[str],
    sources_dicts: list[dict],
    extra_map: dict[str, Path] | None = None,
    link_mode: str = "copy",
    verbose: bool = True,
):
    images_out = dest_split_root / "images"
    labels_out = dest_split_root / "labels"
    images_out.mkdir(parents=True, exist_ok=True)
    labels_out.mkdir(parents=True, exist_ok=True)

    total = pos = neg = miss = 0

    for key in keys:
        images_dir = _resolve_images_dir(key, sources_dicts, extra_map)
        labels_dir = _labels_sibling(images_dir)
        if verbose:
            print(f"[{dest_split_root.name}] add {key}  imgs={images_dir}  lbls={labels_dir}")

        imgs = list_images(images_dir)
        for img in imgs:
            stem, ext = img.stem, img.suffix.lower()
            dst_img = images_out / f"{key}__{stem}{ext}"
            dst_lbl = labels_out / f"{key}__{stem}.txt"

            _copy_or_link(img, dst_img, link_mode)

            lbl_src = labels_dir / f"{stem}.txt"
            if lbl_src.exists():
                shutil.copy2(lbl_src, dst_lbl)
                if dst_lbl.stat().st_size > 0: pos += 1
                else:                           neg += 1
            else:
                _ensure_empty(dst_lbl)
                neg += 1
                miss += 1

            total += 1

    if verbose:
        print(f"[{dest_split_root.name}] images -> {images_out}")
        print(f"[{dest_split_root.name}] labels -> {labels_out}")
        print(f"TOTAL={total}  POS={pos}  NEG={neg}  MISSING_LABELS={miss}")

    return images_out, labels_out

# ---------------- USE IT ----------------
dest_root =  ROOT / "data" / "detection2" / "yolo_split2"
train_dest = dest_root / "train"
val_dest   = dest_root / "val"


# external paths only for items not in train/valid sources (e.g., Kvasir)
extra_map = {
    "kvasir_images": (ROOT / "data/kvasir-seg/images"),
}

# merge (uses train_sources/valid_sources automatically)
merge_yolo_split_keys(train_dest, train_list, [train_sources], extra_map, link_mode="copy")
merge_yolo_split_keys(val_dest,   val_list,   [valid_sources], extra_map, link_mode="copy")
# Out:
# [train] add single  imgs=..\data\detection2\train\images_single  lbls=..\data\detection2\train\images_single_yolo_labels
# [train] add seq10  imgs=..\data\detection2\train\seq\seq10\images_seq10  lbls=..\data\detection2\train\seq\seq10\images_seq10_yolo_labels
# [train] add seq11  imgs=..\data\detection2\train\seq\seq11\images_seq11  lbls=..\data\detection2\train\seq\seq11\images_seq11_yolo_labels
# [train] add seq12  imgs=..\data\detection2\train\seq\seq12\images_seq12  lbls=..\data\detection2\train\seq\seq12\images_seq12_yolo_labels
# [train] add seq13  imgs=..\data\detection2\train\seq\seq13\images_seq13  lbls=..\data\detection2\train\seq\seq13\images_seq13_yolo_labels
# [train] add seq16_neg  imgs=..\data\detection2\train\seq\seq16_neg  lbls=..\data\detection2\train\seq\seq16_neg_yolo_labels
# [train] add seq1_neg  imgs=..\data\detection2\train\seq\seq1_neg  lbls=..\data\detection2\train\seq\seq1_neg_yolo_labels
# [train] add seq2  imgs=..\data\detection2\train\seq\seq2\images_seq2  lbls=..\data\detection2\train\seq\seq2\images_seq2_yolo_labels
# [train] add seq22_neg  imgs=..\data\detection2\train\seq\seq22_neg  lbls=..\data\detection2\train\seq\seq22_neg_yolo_labels
# [train] add seq2_neg  imgs=..\data\detection2\train\seq\seq2_neg  lbls=..\data\detection2\train\seq\seq2_neg_yolo_labels
# [train] add seq3  imgs=..\data\detection2\train\seq\seq3\images_seq3  lbls=..\data\detection2\train\seq\seq3\images_seq3_yolo_labels
# [train] add seq3_neg  imgs=..\data\detection2\train\seq\seq3_neg  lbls=..\data\detection2\train\seq\seq3_neg_yolo_labels
# [train] add seq4  imgs=..\data\detection2\train\seq\seq4\images_seq4  lbls=..\data\detection2\train\seq\seq4\images_seq4_yolo_labels
# [train] add seq4_neg  imgs=..\data\detection2\train\seq\seq4_neg  lbls=..\data\detection2\train\seq\seq4_neg_yolo_labels
# [train] add seq5  imgs=..\data\detection2\train\seq\seq5\images_seq5  lbls=..\data\detection2\train\seq\seq5\images_seq5_yolo_labels
# [train] add seq5_neg  imgs=..\data\detection2\train\seq\seq5_neg  lbls=..\data\detection2\train\seq\seq5_neg_yolo_labels
# [train] add seq6  imgs=..\data\detection2\train\seq\seq6\images_seq6  lbls=..\data\detection2\train\seq\seq6\images_seq6_yolo_labels
# [train] add seq6_neg  imgs=..\data\detection2\train\seq\seq6_neg  lbls=..\data\detection2\train\seq\seq6_neg_yolo_labels
# [train] add seq7_neg  imgs=..\data\detection2\train\seq\seq7_neg  lbls=..\data\detection2\train\seq\seq7_neg_yolo_labels
# [train] add seq8  imgs=..\data\detection2\train\seq\seq8\images_seq8  lbls=..\data\detection2\train\seq\seq8\images_seq8_yolo_labels
# [train] add seq8_neg  imgs=..\data\detection2\train\seq\seq8_neg  lbls=..\data\detection2\train\seq\seq8_neg_yolo_labels
# [train] add seq9  imgs=..\data\detection2\train\seq\seq9\images_seq9  lbls=..\data\detection2\train\seq\seq9\images_seq9_yolo_labels
# [train] add seq9_neg  imgs=..\data\detection2\train\seq\seq9_neg  lbls=..\data\detection2\train\seq\seq9_neg_yolo_labels
# [train] images -> ..\data\detection2\yolo_split2\train\images
# [train] labels -> ..\data\detection2\yolo_split2\train\labels
# TOTAL=4169  POS=2083  NEG=2086  MISSING_LABELS=0
# [val] add single  imgs=..\data\detection2\valid\images_single  lbls=..\data\detection2\valid\images_single_yolo_labels
# [val] add seq14  imgs=..\data\detection2\valid\seq\seq14\images_seq14  lbls=..\data\detection2\valid\seq\seq14\images_seq14_yolo_labels
# [val] add seq15_neg  imgs=..\data\detection2\valid\seq\seq15_neg  lbls=..\data\detection2\valid\seq\seq15_neg_yolo_labels
# [val] add kvasir_images  imgs=..\data\kvasir-seg\images  lbls=..\data\kvasir-seg\images_yolo_labels
# [val] images -> ..\data\detection2\yolo_split2\val\images
# [val] labels -> ..\data\detection2\yolo_split2\val\labels
# TOTAL=1666  POS=1328  NEG=338  MISSING_LABELS=0
# (WindowsPath('../data/detection2/yolo_split2/val/images'),
#  WindowsPath('../data/detection2/yolo_split2/val/labels'))

# %%
from pathlib import Path

path_val = (ROOT / "data" / "detection2" / "yolo_split2").resolve().as_posix()
yaml_text = f"""\
path: {path_val}
train: train/images
val: val/images
# test: test/images
nc: 1
names: [polyp]
"""

dest = ROOT / "configs" / "data2.yaml"
dest.parent.mkdir(parents=True, exist_ok=True)
dest.write_text(yaml_text, encoding="utf-8")
print("Wrote:", dest)
# Out:
# Wrote: ..\configs\data2.yaml
